# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv("mega.csv", header = None)
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.head()
# Out:
# 0  NaN            fix                     Player Pos   G   Tm Age  GS  MP.x  \
# 1  1.0    aaronbrooks     Aaron Brooks\brookaa01  PG  82  CHI  30  21    23
# 2  2.0   alananderson    Alan Anderson\anderal01  SG  74  BRK  32  19  23.6
# 3  3.0   alexisajinca    Alexis Ajinca\ajincal01   C  68  NOP  26   8  14.1
# 4  4.0  alfarouqaminu  Al-Farouq Aminu\aminual01  SF  74  DAL  24   3  18.5
# 5  5.0      alonzogee         Alonzo Gee\geeal01  SF  54  TOT  27   2  12.3
#
# 0   FG   ...     OWS  DWS   WS  WS.48  OBPM  DBPM   BPM VORP total.contract  \
# 1  4.2   ...     1.7  1.5  3.3  0.083     1  -2.4  -1.4  0.3        2250000
# 2  2.6   ...     1.7  1.1  2.7  0.075     0  -0.5  -0.5  0.6        4000000
# 3  2.7   ...     1.9  1.2  3.2  0.159  -0.5   0.6   0.2  0.5       19200000
# 4    2   ...     1.2    2  3.3  0.115  -0.5   2.9   2.4  1.5       30000000
# 5  1.6   ...     0.6  0.6  1.2  0.086  -1.3   0.3    -1  0.2        2699400
#
# 0  average
# 1  2250000
# 2  4000000
# 3  4800000
# 4  7500000
# 5  1349700
#
# [5 rows x 54 columns]

# %% [markdown]
# # 2015 Salary Cap: 70,000,000
# Now organize players based on % of salary cap
# 1. < 2% (min)
# 2. 2-4% (Vet Min)
# 3. 4-7% (MLE, Bi-annual)
# 4. 7-10%
# 5. 10-13%
# 6. 13-16%
# 7. 16-19%
# 8. /> 19% (Maxes)

# %%
def salGroup(x):
    yearCap = 70000000
    if x < 0.02*yearCap:
        return 1
    elif x >= 0.02*yearCap and x < 0.04*yearCap:
        return 2
    elif x >= 0.04*yearCap and x < 0.07*yearCap:
        return 3
    elif x >= 0.07*yearCap and x < 0.10*yearCap:
        return 4
    elif x >= 0.10*yearCap and x < 0.13*yearCap:
        return 5
    elif x >= 0.13*yearCap and x < 0.16*yearCap:
        return 6
    elif x >= 0.16*yearCap and x < 0.19*yearCap:
        return 7
    else:
        return 8

# %%
df_1 = df[['fix','FG','PF','DRB','TOV','MP.y','PER','WS','OBPM','average']]
cols = df_1.columns.drop('fix')
df_1[cols] = df_1[cols].apply(pd.to_numeric, errors = 'coerce')
df_1["Cluster"] = df_1['average'].apply(salGroup)
df_1 = df_1.drop('average',axis=1)
df_1.head()
# Out:
# /home/konner/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /home/konner/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0            fix   FG   PF  DRB  TOV  MP.y   PER   WS  OBPM  Cluster
# 1    aaronbrooks  4.2  2.3  1.6  1.9  1885  14.4  3.3   1.0        2
# 2   alananderson  2.6  2.0  2.3  0.8  1744  10.6  2.7   0.0        3
# 3   alexisajinca  2.7  2.2  3.1  1.0   957  19.9  3.2  -0.5        3
# 4  alfarouqaminu  2.0  1.9  3.1  0.7  1366  14.4  3.3  -0.5        5
# 5      alonzogee  1.6  1.1  1.1  0.6   662  13.0  1.2  -1.3        1

# %%
df_1['Cluster'].plot.hist(8,alpha=0.5)
plt.show()

# %%
labels = np.asarray(df_1.Cluster)
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(labels)

labels = le.transform(labels)
df_features = df_1.to_dict(orient='records')

# %%
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer()
features = vec.fit_transform(df_features).toarray()

# %%
##### split up in test and training data ####
from sklearn.model_selection import train_test_split

features_train, features_test, labels_train, labels_test = train_test_split(
	features, labels, 
	test_size=0.33, random_state=42)

# %%
#### Fit to random forests ####

# Random Forests Classifier
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(
	min_samples_split=3,
	criterion="entropy"
	)

# %%
#from sklearn.svm import SVC
#clf = SVC()

# %%
clf.fit(features_train, labels_train)

# find the accuracy of the model
acc_test = clf.score(features_test, labels_test)
acc_train = clf.score(features_train, labels_train)
print ("Train Accuracy:", acc_train)
print ("Test Accuracy:", acc_test)
# Out:
# Train Accuracy: 0.909090909091
# Test Accuracy: 0.615384615385

# %%
#Plot best splits
acc_tests = [0] * 9
acc_trains = [0] * 9
for e in range(10):
    for i in range(2,11):
        clf = RandomForestClassifier(
        min_samples_split=i,
        criterion="entropy"
        )
        clf.fit(features_train, labels_train)
        acc_tests[i-2] += clf.score(features_test, labels_test)
        acc_trains[i-2] += clf.score(features_train, labels_train)

acc_tests = [x/10 for x in acc_tests]
acc_trains = [x/10 for x in acc_trains]
x = np.arange(2,11,1)
plt.plot(x,acc_tests)
plt.show()

# %%
pred = clf.predict(features_test)
#### Figure out what kind of mistakes it makes ####
from sklearn.metrics import recall_score, precision_score

precision = precision_score(labels_test, pred, average="weighted")
recall = recall_score(labels_test, pred, average="weighted")

print ("Precision:", precision)
print ("Recall:", recall)
# Out:
# Precision: 0.603773133185
# Recall: 0.615384615385
# /home/konner/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
plt.hist(labels_test,8,alpha=0.5)
plt.show()

# %%
check = df_feature_selected.drop(['Cluster','average.salary','fix'], axis = 1)
check0 = check.iloc[0]
list(check)
df_features
# Out:
# [{'Age': 30,
#   'BLK': 0.2,
#   'BLK.': 0.6,
#   'BPM': -1.4,
#   'Cluster': 2,
#   'DBPM': -2.4,
#   'FG': 4.2,
#   'FT': 1.8,
#   'FTA': 2.1,
#   'GS': 21,
#   'ORB': 0.4,
#   'STL': 0.7,
#   'STL.': 1.5,
#   'TOV.': 14.9,
#   'VORP': 0.3,
#   'WS': 3.3,
#   'WS.48': 0.083,
#   'average.salary': 2250000,
#   'eFG.': 0.495,
#   'fix': 'aaronbrooks'},
#  {'Age': 19,
#   'BLK': 0.5,
#   'BLK.': 2.2,
#   'BPM': -2.8,
#   'Cluster': 3,
#   'DBPM': 0.0,
#   'FG': 2.0,
#   'FT': 0.9,
#   'FTA': 1.3,
#   'GS': 8,
#   'ORB': 1.0,
#   'STL': 0.4,
#   'STL.': 1.3,
#   'TOV.': 13.9,
#   'VORP': -0.2,
#   'WS': 1.0,
#   'WS.48': 0.06,
#   'average.salary': 4504865,
#   'eFG.': 0.478,
#   'fix': 'aarongordon'},
#  {'Age': 23,
#   'BLK': 0.3,
#   'BLK.': 1.0,
#   'BPM': -5.9,
#   'Cluster': 2,
#   'DBPM': -1.3,
#   'FG': 2.8,
#   'FT': 0.9,
#   'FTA': 1.4,
#   'GS': 22,
#   'ORB': 1.5,
#   'STL': 0.6,
#   'STL.': 1.3,
#   'TOV.': 15.5,
#   'VORP': -0.7,
#   'WS': -0.5,
#   'WS.48': -0.033,
#   'average.salary': 1938800,
#   'eFG.': 0.41600000000000004,
#   'fix': 'adreianpayne'},
#  {'Age': 32,
#   'BLK': 0.1,
#   'BLK.': 0.2,
#   'BPM': -0.5,
#   'Cluster': 3,
#   'DBPM': -0.5,
#   'FG': 2.6,
#   'FT': 1.1,
#   'FTA': 1.4,
#   'GS': 19,
#   'ORB': 0.4,
#   'STL': 0.8,
#   'STL.': 1.7,
#   'TOV.': 11.0,
#   'VORP': 0.6,
#   'WS': 2.7,
#   'WS.48': 0.075,
#   'average.salary': 4000000,
#   'eFG.': 0.526,
#   'fix': 'alananderson'},
#  {'Age': 23,
#   'BLK': 0.2,
#   'BLK.': 0.4,
#   'BPM': -1.6,
#   'Cluster': 6,
#   'DBPM': -1.1,
#   'FG': 4.5,
#   'FT': 3.9,
#   'FTA': 4.8,
#   'GS': 27,
#   'ORB': 0.7,
#   'STL': 0.6,
#   'STL.': 1.0,
#   'TOV.': 12.7,
#   'VORP': 0.1,
#   'WS': 1.7,
#   'WS.48': 0.08900000000000001,
#   'average.salary': 10500000,
#   'eFG.': 0.447,
#   'fix': 'alecburks'},
#  {'Age': 26,
#   'BLK': 0.8,
#   'BLK.': 4.0,
#   'BPM': 0.2,
#   'Cluster': 4,
#   'DBPM': 0.6,
#   'FG': 2.7,
#   'FT': 1.2,
#   'FTA': 1.5,
#   'GS': 8,
#   'ORB': 1.5,
#   'STL': 0.3,
#   'STL.': 1.2,
#   'TOV.': 15.6,
#   'VORP': 0.5,
#   'WS': 3.2,
#   'WS.48': 0.159,
#   'average.salary': 5050000,
#   'eFG.': 0.55,
#   'fix': 'alexisajinca'},
#  {'Age': 21,
#   'BLK': 1.5,
#   'BLK.': 5.3,
#   'BPM': -1.0,
#   'Cluster': 3,
#   'DBPM': 2.3,
#   'FG': 2.6,
#   'FT': 1.1,
#   'FTA': 1.5,
#   'GS': 44,
#   'ORB': 2.1,
#   'STL': 0.5,
#   'STL.': 1.1,
#   'TOV.': 15.7,
#   'VORP': 0.4,
#   'WS': 3.4,
#   'WS.48': 0.107,
#   'average.salary': 3943345,
#   'eFG.': 0.508,
#   'fix': 'alexlen'},
#  {'Age': 24,
#   'BLK': 0.8,
#   'BLK.': 3.7,
#   'BPM': 2.4,
#   'Cluster': 5,
#   'DBPM': 2.9,
#   'FG': 2.0,
#   'FT': 1.1,
#   'FTA': 1.6,
#   'GS': 3,
#   'ORB': 1.5,
#   'STL': 0.9,
#   'STL.': 2.6,
#   'TOV.': 11.9,
#   'VORP': 1.5,
#   'WS': 3.3,
#   'WS.48': 0.115,
#   'average.salary': 7500000,
#   'eFG.': 0.45899999999999996,
#   'fix': 'alfarouqaminu'},
#  {'Age': 28,
#   'BLK': 1.3,
#   'BLK.': 3.5,
#   'BPM': 3.8,
#   'Cluster': 7,
#   'DBPM': 2.5,
#   'FG': 6.8,
#   'FT': 1.4,
#   'FTA': 1.9,
#   'GS': 76,
#   'ORB': 1.7,
#   'STL': 0.9,
#   'STL.': 1.5,
#   'TOV.': 8.9,
#   'VORP': 3.4,
#   'WS': 8.7,
#   'WS.48': 0.179,
#   'average.salary': 12000000,
#   'eFG.': 0.544,
#   'fix': 'alhorford'},
#  {'Age': 30,
#   'BLK': 1.3,
#   'BLK.': 3.3,
#   'BPM': 0.2,
#   'Cluster': 8,
#   'DBPM': 1.6,
#   'FG': 7.5,
#   'FT': 1.7,
#   'FTA': 2.5,
#   'GS': 61,
#   'ORB': 1.5,
#   'STL': 0.7,
#   'STL.': 1.2,
#   'TOV.': 5.9,
#   'VORP': 1.1,
#   'WS': 4.7,
#   'WS.48': 0.113,
#   'average.salary': 13500000,
#   'eFG.': 0.48200000000000004,
#   'fix': 'aljefferson'},
#  {'Age': 22,
#   'BLK': 0.3,
#   'BLK.': 1.6,
#   'BPM': -0.3,
#   'Cluster': 1,
#   'DBPM': 1.0,
#   'FG': 1.2,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 9,
#   'ORB': 0.1,
#   'STL': 0.4,
#   'STL.': 1.4,
#   'TOV.': 8.6,
#   'VORP': 0.3,
#   'WS': 1.3,
#   'WS.48': 0.08800000000000001,
#   'average.salary': 878092,
#   'eFG.': 0.51,
#   'fix': 'allencrabbe'},
#  {'Age': 27,
#   'BLK': 0.1,
#   'BLK.': 0.8,
#   'BPM': -1.0,
#   'Cluster': 1,
#   'DBPM': 0.3,
#   'FG': 1.6,
#   'FT': 1.0,
#   'FTA': 1.4,
#   'GS': 2,
#   'ORB': 0.7,
#   'STL': 0.6,
#   'STL.': 2.7,
#   'TOV.': 13.0,
#   'VORP': 0.2,
#   'WS': 1.2,
#   'WS.48': 0.086,
#   'average.salary': 1349700,
#   'eFG.': 0.503,
#   'fix': 'alonzogee'},
#  {'Age': 32,
#   'BLK': 0.6,
#   'BLK.': 2.5,
#   'BPM': -1.4,
#   'Cluster': 2,
#   'DBPM': -1.3,
#   'FG': 4.6,
#   'FT': 2.3,
#   'FTA': 3.2,
#   'GS': 15,
#   'ORB': 1.9,
#   'STL': 0.5,
#   'STL.': 1.2,
#   'TOV.': 12.0,
#   'VORP': 0.2,
#   'WS': 3.6,
#   'WS.48': 0.138,
#   'average.salary': 1499187,
#   'eFG.': 0.557,
#   'fix': 'amarestoudemire'},
#  {'Age': 27,
#   'BLK': 0.8,
#   'BLK.': 2.4,
#   'BPM': 1.8,
#   'Cluster': 7,
#   'DBPM': 1.0,
#   'FG': 4.0,
#   'FT': 1.1,
#   'FTA': 1.7,
#   'GS': 72,
#   'ORB': 2.1,
#   'STL': 0.6,
#   'STL.': 1.1,
#   'TOV.': 16.0,
#   'VORP': 1.9,
#   'WS': 5.1,
#   'WS.48': 0.124,
#   'average.salary': 12000000,
#   'eFG.': 0.5920000000000001,
#   'fix': 'amirjohnson'},
#  {'Age': 32,
#   'BLK': 0.6,
#   'BLK.': 2.0,
#   'BPM': 0.9,
#   'Cluster': 1,
#   'DBPM': 1.0,
#   'FG': 4.3,
#   'FT': 1.3,
#   'FTA': 1.7,
#   'GS': 26,
#   'ORB': 2.2,
#   'STL': 0.7,
#   'STL.': 1.6,
#   'TOV.': 13.7,
#   'VORP': 0.5,
#   'WS': 1.9,
#   'WS.48': 0.145,
#   'average.salary': 458575,
#   'eFG.': 0.555,
#   'fix': 'andersonvarejao'},
#  {'Age': 21,
#   'BLK': 1.9,
#   'BLK.': 4.8,
#   'BPM': -0.2,
#   'Cluster': 2,
#   'DBPM': 1.1,
#   'FG': 6.0,
#   'FT': 1.7,
#   'FTA': 4.5,
#   'GS': 82,
#   'ORB': 5.3,
#   'STL': 0.9,
#   'STL.': 1.5,
#   'TOV.': 9.7,
#   'VORP': 1.2,
#   'WS': 7.7,
#   'WS.48': 0.147,
#   'average.salary': 2664793,
#   'eFG.': 0.514,
#   'fix': 'andredrummond'},
#  {'Age': 31,
#   'BLK': 0.3,
#   'BLK.': 0.9,
#   'BPM': 1.6,
#   'Cluster': 7,
#   'DBPM': 1.5,
#   'FG': 3.0,
#   'FT': 0.9,
#   'FTA': 1.5,
#   'GS': 0,
#   'ORB': 0.6,
#   'STL': 1.2,
#   'STL.': 2.1,
#   'TOV.': 13.9,
#   'VORP': 1.9,
#   'WS': 5.1,
#   'WS.48': 0.11699999999999999,
#   'average.salary': 12000000,
#   'eFG.': 0.54,
#   'fix': 'andreiguodala'},
#  {'Age': 38,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -3.0,
#   'Cluster': 1,
#   'DBPM': -1.8,
#   'FG': 1.8,
#   'FT': 0.7,
#   'FTA': 1.0,
#   'GS': 0,
#   'ORB': 0.5,
#   'STL': 0.4,
#   'STL.': 1.3,
#   'TOV.': 24.3,
#   'VORP': -0.3,
#   'WS': 2.2,
#   'WS.48': 0.084,
#   'average.salary': 396844,
#   'eFG.': 0.512,
#   'fix': 'andremiller'},
#  {'Age': 23,
#   'BLK': 0.4,
#   'BLK.': 1.8,
#   'BPM': 0.3,
#   'Cluster': 1,
#   'DBPM': 2.1,
#   'FG': 1.4,
#   'FT': 0.3,
#   'FTA': 0.7,
#   'GS': 65,
#   'ORB': 0.9,
#   'STL': 0.8,
#   'STL.': 2.1,
#   'TOV.': 17.2,
#   'VORP': 0.7,
#   'WS': 2.1,
#   'WS.48': 0.079,
#   'average.salary': 1323828,
#   'eFG.': 0.51,
#   'fix': 'andreroberson'},
#  {'Age': 30,
#   'BLK': 1.7,
#   'BLK.': 5.3,
#   'BPM': 4.1,
#   'Cluster': 7,
#   'DBPM': 5.5,
#   'FG': 3.0,
#   'FT': 0.3,
#   'FTA': 0.6,
#   'GS': 65,
#   'ORB': 2.1,
#   'STL': 0.6,
#   'STL.': 1.2,
#   'TOV.': 22.1,
#   'VORP': 2.4,
#   'WS': 5.2,
#   'WS.48': 0.159,
#   'average.salary': 12000000,
#   'eFG.': 0.563,
#   'fix': 'andrewbogut'},
#  {'Age': 25,
#   'BLK': 0.3,
#   'BLK.': 2.0,
#   'BPM': -6.2,
#   'Cluster': 2,
#   'DBPM': -2.1,
#   'FG': 2.1,
#   'FT': 0.4,
#   'FTA': 0.6,
#   'GS': 3,
#   'ORB': 0.4,
#   'STL': 0.2,
#   'STL.': 0.6,
#   'TOV.': 10.7,
#   'VORP': -0.5,
#   'WS': 0.1,
#   'WS.48': 0.006999999999999999,
#   'average.salary': 1706648,
#   'eFG.': 0.47100000000000003,
#   'fix': 'andrewnicholson'},
#  {'Age': 19,
#   'BLK': 0.6,
#   'BLK.': 1.3,
#   'BPM': -2.3,
#   'Cluster': 4,
#   'DBPM': -1.8,
#   'FG': 6.1,
#   'FT': 4.3,
#   'FTA': 5.7,
#   'GS': 82,
#   'ORB': 1.6,
#   'STL': 1.0,
#   'STL.': 1.5,
#   'TOV.': 11.7,
#   'VORP': -0.2,
#   'WS': 2.1,
#   'WS.48': 0.034,
#   'average.salary': 6212561,
#   'eFG.': 0.45399999999999996,
#   'fix': 'andrewwiggins'},
#  {'Age': 21,
#   'BLK': 2.9,
#   'BLK.': 6.2,
#   'BPM': 7.1,
#   'Cluster': 4,
#   'DBPM': 3.0,
#   'FG': 9.4,
#   'FT': 5.5,
#   'FTA': 6.8,
#   'GS': 68,
#   'ORB': 2.5,
#   'STL': 1.5,
#   'STL.': 2.1,
#   'TOV.': 6.3,
#   'VORP': 5.7,
#   'WS': 14.0,
#   'WS.48': 0.27399999999999997,
#   'average.salary': 5799503,
#   'eFG.': 0.536,
#   'fix': 'anthonydavis'},
#  {'Age': 29,
#   'BLK': 0.1,
#   'BLK.': 0.5,
#   'BPM': 0.6,
#   'Cluster': 3,
#   'DBPM': -1.8,
#   'FG': 3.9,
#   'FT': 1.1,
#   'FTA': 1.2,
#   'GS': 0,
#   'ORB': 0.5,
#   'STL': 0.7,
#   'STL.': 1.5,
#   'TOV.': 5.5,
#   'VORP': 1.2,
#   'WS': 5.7,
#   'WS.48': 0.151,
#   'average.salary': 3344000,
#   'eFG.': 0.578,
#   'fix': 'anthonymorrow'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 0.9,
#   'BPM': -0.6,
#   'Cluster': 3,
#   'DBPM': -1.1,
#   'FG': 2.1,
#   'FT': 0.7,
#   'FTA': 0.9,
#   'GS': 11,
#   'ORB': 0.7,
#   'STL': 0.3,
#   'STL.': 0.9,
#   'TOV.': 10.8,
#   'VORP': 0.5,
#   'WS': 2.7,
#   'WS.48': 0.092,
#   'average.salary': 3000000,
#   'eFG.': 0.545,
#   'fix': 'anthonytolliver'},
#  {'Age': 20,
#   'BLK': 0.2,
#   'BLK.': 1.3,
#   'BPM': -4.5,
#   'Cluster': 1,
#   'DBPM': -1.2,
#   'FG': 1.9,
#   'FT': 1.5,
#   'FTA': 2.0,
#   'GS': 2,
#   'ORB': 0.7,
#   'STL': 0.4,
#   'STL.': 1.7,
#   'TOV.': 16.8,
#   'VORP': -0.3,
#   'WS': 0.2,
#   'WS.48': 0.013999999999999999,
#   'average.salary': 1357732,
#   'eFG.': 0.423,
#   'fix': 'archiegoodwin'},
#  {'Age': 28,
#   'BLK': 0.3,
#   'BLK.': 1.5,
#   'BPM': -1.0,
#   'Cluster': 4,
#   'DBPM': -0.2,
#   'FG': 2.6,
#   'FT': 1.3,
#   'FTA': 1.5,
#   'GS': 17,
#   'ORB': 1.6,
#   'STL': 0.2,
#   'STL.': 0.7,
#   'TOV.': 14.8,
#   'VORP': 0.3,
#   'WS': 3.9,
#   'WS.48': 0.166,
#   'average.salary': 6500000,
#   'eFG.': 0.5670000000000001,
#   'fix': 'aronbaynes'},
#  {'Age': 29,
#   'BLK': 0.1,
#   'BLK.': 0.2,
#   'BPM': -1.8,
#   'Cluster': 5,
#   'DBPM': -1.3,
#   'FG': 4.8,
#   'FT': 2.1,
#   'FTA': 2.5,
#   'GS': 72,
#   'ORB': 0.3,
#   'STL': 0.5,
#   'STL.': 0.8,
#   'TOV.': 10.7,
#   'VORP': 0.1,
#   'WS': 2.6,
#   'WS.48': 0.05,
#   'average.salary': 8000000,
#   'eFG.': 0.491,
#   'fix': 'arronafflalo'},
#  {'Age': 22,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': -2.9,
#   'Cluster': 3,
#   'DBPM': -1.2,
#   'FG': 2.7,
#   'FT': 1.1,
#   'FTA': 1.7,
#   'GS': 5,
#   'ORB': 0.4,
#   'STL': 0.6,
#   'STL.': 1.6,
#   'TOV.': 10.5,
#   'VORP': -0.4,
#   'WS': 1.5,
#   'WS.48': 0.046,
#   'average.salary': 3227451,
#   'eFG.': 0.449,
#   'fix': 'austinrivers'},
#  {'Age': 24,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': -1.7,
#   'Cluster': 5,
#   'DBPM': -0.9,
#   'FG': 5.6,
#   'FT': 1.0,
#   'FTA': 1.3,
#   'GS': 77,
#   'ORB': 0.6,
#   'STL': 1.1,
#   'STL.': 1.7,
#   'TOV.': 9.4,
#   'VORP': 0.2,
#   'WS': 2.5,
#   'WS.48': 0.049,
#   'average.salary': 8000000,
#   'eFG.': 0.49,
#   'fix': 'averybradley'},
#  {'Age': 21,
#   'BLK': 0.2,
#   'BLK.': 0.6,
#   'BPM': -0.8,
#   'Cluster': 3,
#   'DBPM': -1.3,
#   'FG': 4.4,
#   'FT': 1.6,
#   'FTA': 2.0,
#   'GS': 82,
#   'ORB': 0.4,
#   'STL': 0.9,
#   'STL.': 1.5,
#   'TOV.': 13.3,
#   'VORP': 0.8,
#   'WS': 2.5,
#   'WS.48': 0.045,
#   'average.salary': 3271931,
#   'eFG.': 0.521,
#   'fix': 'benmclemore'},
#  {'Age': 32,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -0.8,
#   'Cluster': 1,
#   'DBPM': -1.0,
#   'FG': 3.1,
#   'FT': 1.1,
#   'FTA': 1.3,
#   'GS': 12,
#   'ORB': 0.3,
#   'STL': 0.6,
#   'STL.': 1.6,
#   'TOV.': 13.9,
#   'VORP': 0.5,
#   'WS': 3.6,
#   'WS.48': 0.115,
#   'average.salary': 191512,
#   'eFG.': 0.513,
#   'fix': 'benoudrih'},
#  {'Age': 22,
#   'BLK': 1.5,
#   'BLK.': 6.3,
#   'BPM': -0.4,
#   'Cluster': 3,
#   'DBPM': 2.8,
#   'FG': 1.6,
#   'FT': 1.6,
#   'FTA': 2.7,
#   'GS': 21,
#   'ORB': 2.5,
#   'STL': 0.3,
#   'STL.': 0.7,
#   'TOV.': 16.5,
#   'VORP': 0.5,
#   'WS': 4.0,
#   'WS.48': 0.156,
#   'average.salary': 2877315,
#   'eFG.': 0.5429999999999999,
#   'fix': 'bismackbiyombo'},
#  {'Age': 25,
#   'BLK': 0.5,
#   'BLK.': 1.2,
#   'BPM': 4.1,
#   'Cluster': 8,
#   'DBPM': 1.0,
#   'FG': 8.6,
#   'FT': 4.6,
#   'FTA': 6.4,
#   'GS': 67,
#   'ORB': 1.9,
#   'STL': 0.9,
#   'STL.': 1.4,
#   'TOV.': 10.2,
#   'VORP': 3.6,
#   'WS': 9.0,
#   'WS.48': 0.183,
#   'average.salary': 18907725,
#   'eFG.': 0.506,
#   'fix': 'blakegriffin'},
#  {'Age': 25,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -1.8,
#   'Cluster': 3,
#   'DBPM': -1.9,
#   'FG': 3.3,
#   'FT': 1.1,
#   'FTA': 1.4,
#   'GS': 28,
#   'ORB': 0.6,
#   'STL': 0.4,
#   'STL.': 0.9,
#   'TOV.': 11.1,
#   'VORP': 0.1,
#   'WS': 2.4,
#   'WS.48': 0.062,
#   'average.salary': 3425510,
#   'eFG.': 0.532,
#   'fix': 'bojanbogdanovic'},
#  {'Age': 32,
#   'BLK': 0.3,
#   'BLK.': 0.9,
#   'BPM': 0.1,
#   'Cluster': 5,
#   'DBPM': 0.7,
#   'FG': 3.6,
#   'FT': 0.9,
#   'FTA': 1.1,
#   'GS': 15,
#   'ORB': 1.0,
#   'STL': 0.4,
#   'STL.': 0.9,
#   'TOV.': 15.8,
#   'VORP': 1.1,
#   'WS': 3.6,
#   'WS.48': 0.08800000000000001,
#   'average.salary': 7000000,
#   'eFG.': 0.503,
#   'fix': 'borisdiaw'},
#  {'Age': 21,
#   'BLK': 0.3,
#   'BLK.': 0.7,
#   'BPM': 0.5,
#   'Cluster': 3,
#   'DBPM': -0.1,
#   'FG': 5.8,
#   'FT': 2.1,
#   'FTA': 2.6,
#   'GS': 59,
#   'ORB': 0.9,
#   'STL': 1.2,
#   'STL.': 1.8,
#   'TOV.': 11.7,
#   'VORP': 1.3,
#   'WS': 3.7,
#   'WS.48': 0.085,
#   'average.salary': 4663129,
#   'eFG.': 0.489,
#   'fix': 'bradleybeal'},
#  {'Age': 27,
#   'BLK': 1.3,
#   'BLK.': 5.1,
#   'BPM': 3.6,
#   'Cluster': 4,
#   'DBPM': 2.4,
#   'FG': 3.1,
#   'FT': 1.0,
#   'FTA': 1.5,
#   'GS': 7,
#   'ORB': 1.7,
#   'STL': 0.7,
#   'STL.': 1.7,
#   'TOV.': 7.6,
#   'VORP': 2.0,
#   'WS': 6.1,
#   'WS.48': 0.20199999999999999,
#   'average.salary': 5709880,
#   'eFG.': 0.642,
#   'fix': 'brandanwright'},
#  {'Age': 29,
#   'BLK': 0.4,
#   'BLK.': 1.3,
#   'BPM': -0.5,
#   'Cluster': 3,
#   'DBPM': -0.1,
#   'FG': 4.2,
#   'FT': 2.1,
#   'FTA': 2.6,
#   'GS': 43,
#   'ORB': 1.7,
#   'STL': 0.5,
#   'STL.': 1.1,
#   'TOV.': 9.6,
#   'VORP': 0.7,
#   'WS': 5.3,
#   'WS.48': 0.132,
#   'average.salary': 3067500,
#   'eFG.': 0.51,
#   'fix': 'brandonbass'},
#  {'Age': 25,
#   'BLK': 0.1,
#   'BLK.': 0.3,
#   'BPM': 1.8,
#   'Cluster': 5,
#   'DBPM': -2.5,
#   'FG': 5.3,
#   'FT': 2.9,
#   'FTA': 3.5,
#   'GS': 41,
#   'ORB': 0.5,
#   'STL': 1.1,
#   'STL.': 1.9,
#   'TOV.': 12.9,
#   'VORP': 1.1,
#   'WS': 3.3,
#   'WS.48': 0.136,
#   'average.salary': 8000000,
#   'eFG.': 0.47100000000000003,
#   'fix': 'brandonjennings'},
#  {'Age': 23,
#   'BLK': 0.2,
#   'BLK.': 0.4,
#   'BPM': 1.1,
#   'Cluster': 8,
#   'DBPM': -0.7,
#   'FG': 6.0,
#   'FT': 3.1,
#   'FTA': 3.5,
#   'GS': 61,
#   'ORB': 0.4,
#   'STL': 1.4,
#   'STL.': 2.3,
#   'TOV.': 16.1,
#   'VORP': 1.6,
#   'WS': 4.5,
#   'WS.48': 0.106,
#   'average.salary': 14000000,
#   'eFG.': 0.493,
#   'fix': 'brandonknight'},
#  {'Age': 29,
#   'BLK': 0.4,
#   'BLK.': 3.3,
#   'BPM': -6.0,
#   'Cluster': 1,
#   'DBPM': 1.8,
#   'FG': 0.3,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 0,
#   'ORB': 0.1,
#   'STL': 0.2,
#   'STL.': 0.9,
#   'TOV.': 15.8,
#   'VORP': -0.3,
#   'WS': -0.3,
#   'WS.48': -0.055999999999999994,
#   'average.salary': 1208325,
#   'eFG.': 0.231,
#   'fix': 'brandonrush'},
#  {'Age': 29,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -2.5,
#   'Cluster': 1,
#   'DBPM': -1.7,
#   'FG': 2.4,
#   'FT': 0.9,
#   'FTA': 1.0,
#   'GS': 10,
#   'ORB': 0.2,
#   'STL': 0.5,
#   'STL.': 1.3,
#   'TOV.': 10.5,
#   'VORP': -0.2,
#   'WS': 1.8,
#   'WS.48': 0.064,
#   'average.salary': 33588,
#   'eFG.': 0.45799999999999996,
#   'fix': 'brianroberts'},
#  {'Age': 29,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -2.5,
#   'Cluster': 2,
#   'DBPM': -1.7,
#   'FG': 2.4,
#   'FT': 0.9,
#   'FTA': 1.0,
#   'GS': 10,
#   'ORB': 0.2,
#   'STL': 0.5,
#   'STL.': 1.3,
#   'TOV.': 10.5,
#   'VORP': -0.2,
#   'WS': 1.8,
#   'WS.48': 0.064,
#   'average.salary': 2793470,
#   'eFG.': 0.45799999999999996,
#   'fix': 'brianroberts'},
#  {'Age': 29,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -2.5,
#   'Cluster': 2,
#   'DBPM': -1.7,
#   'FG': 2.4,
#   'FT': 0.9,
#   'FTA': 1.0,
#   'GS': 10,
#   'ORB': 0.2,
#   'STL': 0.5,
#   'STL.': 1.3,
#   'TOV.': 10.5,
#   'VORP': -0.2,
#   'WS': 1.8,
#   'WS.48': 0.064,
#   'average.salary': 1897695,
#   'eFG.': 0.45799999999999996,
#   'fix': 'brianroberts'},
#  {'Age': 26,
#   'BLK': 1.8,
#   'BLK.': 4.8,
#   'BPM': 0.2,
#   'Cluster': 8,
#   'DBPM': -0.3,
#   'FG': 7.0,
#   'FT': 3.1,
#   'FTA': 3.8,
#   'GS': 44,
#   'ORB': 3.0,
#   'STL': 0.6,
#   'STL.': 1.1,
#   'TOV.': 8.6,
#   'VORP': 1.1,
#   'WS': 7.0,
#   'WS.48': 0.159,
#   'average.salary': 21165675,
#   'eFG.': 0.513,
#   'fix': 'brooklopez'},
#  {'Age': 19,
#   'BLK': 0.1,
#   'BLK.': 3.5,
#   'BPM': -18.9,
#   'Cluster': 2,
#   'DBPM': -6.3,
#   'FG': 0.5,
#   'FT': 0.0,
#   'FTA': 0.0,
#   'GS': 0,
#   'ORB': 0.1,
#   'STL': 0.0,
#   'STL.': 0.0,
#   'TOV.': 25.0,
#   'VORP': -0.1,
#   'WS': -0.1,
#   'WS.48': -0.275,
#   'average.salary': 1755806,
#   'eFG.': 0.41700000000000004,
#   'fix': 'brunocaboclo'},
#  {'Age': 22,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -4.4,
#   'Cluster': 1,
#   'DBPM': -3.2,
#   'FG': 1.9,
#   'FT': 1.0,
#   'FTA': 1.2,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.3,
#   'STL.': 1.3,
#   'TOV.': 13.5,
#   'VORP': -0.1,
#   'WS': 0.2,
#   'WS.48': 0.067,
#   'average.salary': 4971,
#   'eFG.': 0.47100000000000003,
#   'fix': 'brycecotton'},
#  {'Age': 22,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -4.4,
#   'Cluster': 1,
#   'DBPM': -3.2,
#   'FG': 1.9,
#   'FT': 1.0,
#   'FTA': 1.2,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.3,
#   'STL.': 1.3,
#   'TOV.': 13.5,
#   'VORP': -0.1,
#   'WS': 0.2,
#   'WS.48': 0.067,
#   'average.salary': 14913,
#   'eFG.': 0.47100000000000003,
#   'fix': 'brycecotton'},
#  {'Age': 24,
#   'BLK': 0.1,
#   'BLK.': 1.1,
#   'BPM': -7.7,
#   'Cluster': 1,
#   'DBPM': -1.0,
#   'FG': 0.2,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 1,
#   'ORB': 0.3,
#   'STL': 0.1,
#   'STL.': 1.6,
#   'TOV.': 15.6,
#   'VORP': -0.1,
#   'WS': -0.1,
#   'WS.48': -0.048,
#   'average.salary': 777609,
#   'eFG.': 0.214,
#   'fix': 'cameronbairstow'},
#  {'Age': 24,
#   'BLK': 0.1,
#   'BLK.': 1.1,
#   'BPM': -7.7,
#   'Cluster': 1,
#   'DBPM': -1.0,
#   'FG': 0.2,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 1,
#   'ORB': 0.3,
#   'STL': 0.1,
#   'STL.': 1.6,
#   'TOV.': 15.6,
#   'VORP': -0.1,
#   'WS': -0.1,
#   'WS.48': -0.048,
#   'average.salary': 845059,
#   'eFG.': 0.214,
#   'fix': 'cameronbairstow'},
#  {'Age': 31,
#   'BLK': 0.2,
#   'BLK.': 1.1,
#   'BPM': -3.6,
#   'Cluster': 4,
#   'DBPM': -2.6,
#   'FG': 2.7,
#   'FT': 1.8,
#   'FTA': 2.1,
#   'GS': 15,
#   'ORB': 1.4,
#   'STL': 0.2,
#   'STL.': 0.6,
#   'TOV.': 11.0,
#   'VORP': -0.5,
#   'WS': 2.8,
#   'WS.48': 0.11199999999999999,
#   'average.salary': 6500000,
#   'eFG.': 0.515,
#   'fix': 'carllandry'},
#  {'Age': 30,
#   'BLK': 0.4,
#   'BLK.': 1.0,
#   'BPM': 1.4,
#   'Cluster': 8,
#   'DBPM': -2.2,
#   'FG': 9.0,
#   'FT': 4.7,
#   'FTA': 5.9,
#   'GS': 40,
#   'ORB': 1.8,
#   'STL': 1.0,
#   'STL.': 1.5,
#   'TOV.': 8.9,
#   'VORP': 1.2,
#   'WS': 2.9,
#   'WS.48': 0.09699999999999999,
#   'average.salary': 24812936,
#   'eFG.': 0.48200000000000004,
#   'fix': 'carmeloanthony'},
#  {'Age': 34,
#   'BLK': 0.1,
#   'BLK.': 0.2,
#   'BPM': -1.5,
#   'Cluster': 2,
#   'DBPM': -0.5,
#   'FG': 2.1,
#   'FT': 0.7,
#   'FTA': 0.8,
#   'GS': 21,
#   'ORB': 0.3,
#   'STL': 0.6,
#   'STL.': 1.4,
#   'TOV.': 10.4,
#   'VORP': 0.2,
#   'WS': 2.4,
#   'WS.48': 0.07,
#   'average.salary': 1525423,
#   'eFG.': 0.511,
#   'fix': 'caronbutler'},
#  {'Age': 26,
#   'BLK': 0.3,
#   'BLK.': 0.7,
#   'BPM': 2.5,
#   'Cluster': 8,
#   'DBPM': -0.2,
#   'FG': 5.8,
#   'FT': 2.1,
#   'FTA': 2.9,
#   'GS': 66,
#   'ORB': 1.0,
#   'STL': 1.0,
#   'STL.': 1.6,
#   'TOV.': 9.5,
#   'VORP': 2.5,
#   'WS': 5.5,
#   'WS.48': 0.121,
#   'average.salary': 15361500,
#   'eFG.': 0.542,
#   'fix': 'chandlerparsons'},
#  {'Age': 31,
#   'BLK': 0.5,
#   'BLK.': 1.7,
#   'BPM': -0.9,
#   'Cluster': 5,
#   'DBPM': 0.0,
#   'FG': 2.5,
#   'FT': 0.4,
#   'FTA': 0.5,
#   'GS': 51,
#   'ORB': 0.4,
#   'STL': 0.6,
#   'STL.': 1.3,
#   'TOV.': 13.4,
#   'VORP': 0.5,
#   'WS': 2.1,
#   'WS.48': 0.053,
#   'average.salary': 8000000,
#   'eFG.': 0.532,
#   'fix': 'channingfrye'},
#  {'Age': 30,
#   'BLK': 0.3,
#   'BLK.': 2.6,
#   'BPM': -1.8,
#   'Cluster': 2,
#   'DBPM': -3.1,
#   'FG': 2.3,
#   'FT': 0.3,
#   'FTA': 0.5,
#   'GS': 1,
#   'ORB': 0.5,
#   'STL': 0.2,
#   'STL.': 1.1,
#   'TOV.': 6.9,
#   'VORP': 0.0,
#   'WS': 1.4,
#   'WS.48': 0.096,
#   'average.salary': 1499187,
#   'eFG.': 0.529,
#   'fix': 'charlievillanueva'},
#  {'Age': 26,
#   'BLK': 0.1,
#   'BLK.': 0.6,
#   'BPM': -2.8,
#   'Cluster': 1,
#   'DBPM': -1.9,
#   'FG': 2.5,
#   'FT': 1.0,
#   'FTA': 1.2,
#   'GS': 4,
#   'ORB': 0.5,
#   'STL': 0.7,
#   'STL.': 1.7,
#   'TOV.': 10.3,
#   'VORP': -0.3,
#   'WS': 1.3,
#   'WS.48': 0.049,
#   'average.salary': 258082,
#   'eFG.': 0.5,
#   'fix': 'chasebudinger'},
#  {'Age': 36,
#   'BLK': 1.0,
#   'BLK.': 4.6,
#   'BPM': 1.0,
#   'Cluster': 4,
#   'DBPM': 2.3,
#   'FG': 2.0,
#   'FT': 1.3,
#   'FTA': 1.9,
#   'GS': 20,
#   'ORB': 1.3,
#   'STL': 0.4,
#   'STL.': 1.2,
#   'TOV.': 13.5,
#   'VORP': 0.9,
#   'WS': 3.6,
#   'WS.48': 0.151,
#   'average.salary': 5187500,
#   'eFG.': 0.589,
#   'fix': 'chrisandersen'},
#  {'Age': 30,
#   'BLK': 0.6,
#   'BLK.': 1.4,
#   'BPM': -0.1,
#   'Cluster': 8,
#   'DBPM': -1.0,
#   'FG': 7.8,
#   'FT': 4.1,
#   'FTA': 5.3,
#   'GS': 44,
#   'ORB': 1.0,
#   'STL': 0.9,
#   'STL.': 1.4,
#   'TOV.': 10.1,
#   'VORP': 0.8,
#   'WS': 3.6,
#   'WS.48': 0.111,
#   'average.salary': 23741060,
#   'eFG.': 0.503,
#   'fix': 'chrisbosh'},
#  {'Age': 30,
#   'BLK': 0.2,
#   'BLK.': 1.0,
#   'BPM': -4.3,
#   'Cluster': 1,
#   'DBPM': -1.5,
#   'FG': 2.2,
#   'FT': 0.7,
#   'FTA': 0.9,
#   'GS': 12,
#   'ORB': 0.5,
#   'STL': 0.2,
#   'STL.': 0.7,
#   'TOV.': 15.2,
#   'VORP': -0.5,
#   'WS': -0.1,
#   'WS.48': -0.008,
#   'average.salary': 805000,
#   'eFG.': 0.445,
#   'fix': 'chriscopeland'},
#  {'Age': 32,
#   'BLK': 0.7,
#   'BLK.': 2.8,
#   'BPM': -1.4,
#   'Cluster': 4,
#   'DBPM': 1.1,
#   'FG': 3.8,
#   'FT': 1.0,
#   'FTA': 1.4,
#   'GS': 13,
#   'ORB': 2.0,
#   'STL': 0.2,
#   'STL.': 0.7,
#   'TOV.': 15.4,
#   'VORP': 0.2,
#   'WS': 3.3,
#   'WS.48': 0.11199999999999999,
#   'average.salary': 4908000,
#   'eFG.': 0.515,
#   'fix': 'chriskaman'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 0.4,
#   'BPM': 7.5,
#   'Cluster': 8,
#   'DBPM': 0.0,
#   'FG': 6.9,
#   'FT': 3.5,
#   'FTA': 3.9,
#   'GS': 82,
#   'ORB': 0.6,
#   'STL': 1.9,
#   'STL.': 2.8,
#   'TOV.': 12.7,
#   'VORP': 6.9,
#   'WS': 16.1,
#   'WS.48': 0.27,
#   'average.salary': 21468695,
#   'eFG.': 0.545,
#   'fix': 'chrispaul'},
#  {'Age': 23,
#   'BLK': 0.1,
#   'BLK.': 0.6,
#   'BPM': -0.7,
#   'Cluster': 2,
#   'DBPM': -0.3,
#   'FG': 2.6,
#   'FT': 0.8,
#   'FTA': 1.2,
#   'GS': 3,
#   'ORB': 0.2,
#   'STL': 0.7,
#   'STL.': 2.3,
#   'TOV.': 10.8,
#   'VORP': 0.3,
#   'WS': 1.8,
#   'WS.48': 0.08900000000000001,
#   'average.salary': 2620615,
#   'eFG.': 0.511,
#   'fix': 'cjmccollum'},
#  {'Age': 27,
#   'BLK': 0.4,
#   'BLK.': 1.1,
#   'BPM': -0.3,
#   'Cluster': 3,
#   'DBPM': -1.3,
#   'FG': 4.7,
#   'FT': 1.9,
#   'FTA': 2.3,
#   'GS': 40,
#   'ORB': 0.3,
#   'STL': 0.9,
#   'STL.': 1.7,
#   'TOV.': 7.5,
#   'VORP': 0.8,
#   'WS': 3.6,
#   'WS.48': 0.09300000000000001,
#   'average.salary': 4488838,
#   'eFG.': 0.491,
#   'fix': 'cjmiles'},
#  {'Age': 30,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': 1.5,
#   'Cluster': 4,
#   'DBPM': 0.1,
#   'FG': 3.2,
#   'FT': 2.4,
#   'FTA': 2.9,
#   'GS': 21,
#   'ORB': 0.3,
#   'STL': 1.0,
#   'STL.': 2.1,
#   'TOV.': 16.9,
#   'VORP': 1.3,
#   'WS': 4.0,
#   'WS.48': 0.135,
#   'average.salary': 5000000,
#   'eFG.': 0.518,
#   'fix': 'cjwatson'},
#  {'Age': 24,
#   'BLK': 0.0,
#   'BLK.': 0.8,
#   'BPM': -6.0,
#   'Cluster': 1,
#   'DBPM': -2.7,
#   'FG': 0.8,
#   'FT': 0.1,
#   'FTA': 0.1,
#   'GS': 0,
#   'ORB': 0.0,
#   'STL': 0.1,
#   'STL.': 1.5,
#   'TOV.': 20.5,
#   'VORP': -0.1,
#   'WS': 0.0,
#   'WS.48': -0.024,
#   'average.salary': 1159680,
#   'eFG.': 0.513,
#   'fix': 'cjwilcox'},
#  {'Age': 23,
#   'BLK': 0.3,
#   'BLK.': 1.5,
#   'BPM': -5.2,
#   'Cluster': 1,
#   'DBPM': -1.3,
#   'FG': 1.9,
#   'FT': 0.9,
#   'FTA': 1.2,
#   'GS': 7,
#   'ORB': 0.6,
#   'STL': 0.6,
#   'STL.': 2.0,
#   'TOV.': 14.5,
#   'VORP': -0.5,
#   'WS': -0.4,
#   'WS.48': -0.03,
#   'average.salary': 676198,
#   'eFG.': 0.40700000000000003,
#   'fix': 'cleanthonyearly'},
#  {'Age': 20,
#   'BLK': 0.8,
#   'BLK.': 7.8,
#   'BPM': -7.8,
#   'Cluster': 2,
#   'DBPM': 1.0,
#   'FG': 1.2,
#   'FT': 0.3,
#   'FTA': 1.9,
#   'GS': 0,
#   'ORB': 0.8,
#   'STL': 0.1,
#   'STL.': 0.6,
#   'TOV.': 11.3,
#   'VORP': -0.1,
#   'WS': 0.0,
#   'WS.48': 0.019,
#   'average.salary': 1515672,
#   'eFG.': 0.483,
#   'fix': 'clintcapela'},
#  {'Age': 22,
#   'BLK': 0.8,
#   'BLK.': 2.6,
#   'BPM': 0.4,
#   'Cluster': 3,
#   'DBPM': 2.5,
#   'FG': 2.8,
#   'FT': 2.0,
#   'FTA': 2.6,
#   'GS': 45,
#   'ORB': 1.6,
#   'STL': 0.5,
#   'STL.': 1.2,
#   'TOV.': 12.2,
#   'VORP': 0.9,
#   'WS': 3.8,
#   'WS.48': 0.12300000000000001,
#   'average.salary': 4352528,
#   'eFG.': 0.462,
#   'fix': 'codyzeller'},
#  {'Age': 26,
#   'BLK': 1.1,
#   'BLK.': 5.5,
#   'BPM': 0.9,
#   'Cluster': 1,
#   'DBPM': 3.1,
#   'FG': 2.4,
#   'FT': 0.8,
#   'FTA': 1.0,
#   'GS': 16,
#   'ORB': 1.7,
#   'STL': 0.6,
#   'STL.': 2.0,
#   'TOV.': 15.2,
#   'VORP': 0.7,
#   'WS': 2.2,
#   'WS.48': 0.107,
#   'average.salary': 1163944,
#   'eFG.': 0.478,
#   'fix': 'colealdrich'},
#  {'Age': 28,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': -1.1,
#   'Cluster': 5,
#   'DBPM': -0.3,
#   'FG': 4.3,
#   'FT': 2.1,
#   'FTA': 2.8,
#   'GS': 17,
#   'ORB': 1.0,
#   'STL': 1.4,
#   'STL.': 2.7,
#   'TOV.': 12.7,
#   'VORP': 0.5,
#   'WS': 3.1,
#   'WS.48': 0.071,
#   'average.salary': 7806971,
#   'eFG.': 0.465,
#   'fix': 'coreybrewer'},
#  {'Age': 24,
#   'BLK': 0.4,
#   'BLK.': 3.2,
#   'BPM': -3.7,
#   'Cluster': 1,
#   'DBPM': -0.4,
#   'FG': 1.5,
#   'FT': 0.6,
#   'FTA': 1.1,
#   'GS': 1,
#   'ORB': 0.9,
#   'STL': 0.2,
#   'STL.': 1.0,
#   'TOV.': 9.5,
#   'VORP': -0.2,
#   'WS': 0.8,
#   'WS.48': 0.071,
#   'average.salary': 4971,
#   'eFG.': 0.455,
#   'fix': 'coryjefferson'},
#  {'Age': 23,
#   'BLK': 0.2,
#   'BLK.': 0.9,
#   'BPM': 0.7,
#   'Cluster': 5,
#   'DBPM': 0.5,
#   'FG': 2.6,
#   'FT': 1.3,
#   'FTA': 1.8,
#   'GS': 14,
#   'ORB': 0.6,
#   'STL': 0.6,
#   'STL.': 1.6,
#   'TOV.': 12.4,
#   'VORP': 1.0,
#   'WS': 4.5,
#   'WS.48': 0.149,
#   'average.salary': 7472500,
#   'eFG.': 0.523,
#   'fix': 'coryjoseph'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 0.4,
#   'BPM': 0.5,
#   'Cluster': 4,
#   'DBPM': 0.2,
#   'FG': 3.7,
#   'FT': 1.4,
#   'FTA': 1.7,
#   'GS': 74,
#   'ORB': 0.3,
#   'STL': 1.0,
#   'STL.': 1.7,
#   'TOV.': 10.0,
#   'VORP': 1.5,
#   'WS': 4.8,
#   'WS.48': 0.099,
#   'average.salary': 5337500,
#   'eFG.': 0.518,
#   'fix': 'courtneylee'},
#  {'Age': 34,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -6.4,
#   'Cluster': 1,
#   'DBPM': -1.3,
#   'FG': 0.2,
#   'FT': 0.3,
#   'FTA': 0.3,
#   'GS': 0,
#   'ORB': 0.0,
#   'STL': 0.1,
#   'STL.': 1.2,
#   'TOV.': 3.7,
#   'VORP': -0.1,
#   'WS': 0.0,
#   'WS.48': 0.013000000000000001,
#   'average.salary': 780239,
#   'eFG.': 0.28600000000000003,
#   'fix': 'dahntayjones'},
#  {'Age': 24,
#   'BLK': 0.3,
#   'BLK.': 0.5,
#   'BPM': 5.1,
#   'Cluster': 3,
#   'DBPM': 0.0,
#   'FG': 7.2,
#   'FT': 4.2,
#   'FTA': 4.9,
#   'GS': 82,
#   'ORB': 0.6,
#   'STL': 1.2,
#   'STL.': 1.7,
#   'TOV.': 12.6,
#   'VORP': 5.2,
#   'WS': 10.6,
#   'WS.48': 0.174,
#   'average.salary': 3461292,
#   'eFG.': 0.506,
#   'fix': 'damianlillard'},
#  {'Age': 28,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -2.5,
#   'Cluster': 1,
#   'DBPM': -1.8,
#   'FG': 1.8,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 2,
#   'ORB': 0.1,
#   'STL': 0.2,
#   'STL.': 0.8,
#   'TOV.': 14.7,
#   'VORP': -0.1,
#   'WS': 1.3,
#   'WS.48': 0.061,
#   'average.salary': 1124750,
#   'eFG.': 0.584,
#   'fix': 'damjanrudez'},
#  {'Age': 26,
#   'BLK': 0.3,
#   'BLK.': 1.1,
#   'BPM': 1.3,
#   'Cluster': 8,
#   'DBPM': -1.1,
#   'FG': 3.9,
#   'FT': 2.9,
#   'FTA': 3.2,
#   'GS': 27,
#   'ORB': 0.5,
#   'STL': 0.8,
#   'STL.': 1.6,
#   'TOV.': 8.0,
#   'VORP': 1.2,
#   'WS': 3.9,
#   'WS.48': 0.132,
#   'average.salary': 15050000,
#   'eFG.': 0.496,
#   'fix': 'danilogallinari'},
#  {'Age': 27,
#   'BLK': 1.1,
#   'BLK.': 2.8,
#   'BPM': 5.0,
#   'Cluster': 6,
#   'DBPM': 2.2,
#   'FG': 4.0,
#   'FT': 1.4,
#   'FTA': 1.6,
#   'GS': 80,
#   'ORB': 0.7,
#   'STL': 1.2,
#   'STL.': 2.2,
#   'TOV.': 10.5,
#   'VORP': 4.1,
#   'WS': 7.8,
#   'WS.48': 0.163,
#   'average.salary': 10000000,
#   'eFG.': 0.5660000000000001,
#   'fix': 'dannygreen'},
#  {'Age': 27,
#   'BLK': 0.6,
#   'BLK.': 1.7,
#   'BPM': -1.6,
#   'Cluster': 3,
#   'DBPM': 1.0,
#   'FG': 2.3,
#   'FT': 0.4,
#   'FTA': 0.7,
#   'GS': 27,
#   'ORB': 1.1,
#   'STL': 0.7,
#   'STL.': 1.5,
#   'TOV.': 8.9,
#   'VORP': 0.2,
#   'WS': 1.6,
#   'WS.48': 0.047,
#   'average.salary': 2978250,
#   'eFG.': 0.45899999999999996,
#   'fix': 'dantecunningham'},
#  {'Age': 19,
#   'BLK': 0.2,
#   'BLK.': 0.6,
#   'BPM': -3.8,
#   'Cluster': 3,
#   'DBPM': -1.3,
#   'FG': 1.8,
#   'FT': 0.2,
#   'FTA': 0.4,
#   'GS': 41,
#   'ORB': 0.3,
#   'STL': 0.5,
#   'STL.': 1.2,
#   'TOV.': 21.5,
#   'VORP': -0.8,
#   'WS': -0.1,
#   'WS.48': -0.003,
#   'average.salary': 4081356,
#   'eFG.': 0.44799999999999995,
#   'fix': 'danteexum'},
#  {'Age': 26,
#   'BLK': 0.4,
#   'BLK.': 2.1,
#   'BPM': -1.1,
#   'Cluster': 3,
#   'DBPM': 0.7,
#   'FG': 2.7,
#   'FT': 0.8,
#   'FTA': 1.0,
#   'GS': 4,
#   'ORB': 0.9,
#   'STL': 0.8,
#   'STL.': 2.4,
#   'TOV.': 10.3,
#   'VORP': 0.2,
#   'WS': 0.9,
#   'WS.48': 0.042,
#   'average.salary': 2877315,
#   'eFG.': 0.43799999999999994,
#   'fix': 'darrellarthur'},
#  {'Age': 27,
#   'BLK': 0.3,
#   'BLK.': 0.7,
#   'BPM': 1.5,
#   'Cluster': 4,
#   'DBPM': -1.3,
#   'FG': 5.8,
#   'FT': 3.2,
#   'FTA': 4.1,
#   'GS': 45,
#   'ORB': 0.4,
#   'STL': 1.5,
#   'STL.': 2.2,
#   'TOV.': 15.1,
#   'VORP': 1.4,
#   'WS': 3.8,
#   'WS.48': 0.11599999999999999,
#   'average.salary': 5013559,
#   'eFG.': 0.527,
#   'fix': 'darrencollison'},
#  {'Age': 31,
#   'BLK': 0.5,
#   'BLK.': 2.1,
#   'BPM': 1.4,
#   'Cluster': 2,
#   'DBPM': 2.0,
#   'FG': 3.3,
#   'FT': 1.4,
#   'FTA': 2.1,
#   'GS': 4,
#   'ORB': 1.7,
#   'STL': 0.6,
#   'STL.': 1.7,
#   'TOV.': 12.0,
#   'VORP': 0.8,
#   'WS': 3.2,
#   'WS.48': 0.168,
#   'average.salary': 2085671,
#   'eFG.': 0.511,
#   'fix': 'davidlee'},
#  {'Age': 34,
#   'BLK': 0.7,
#   'BLK.': 2.0,
#   'BPM': 1.7,
#   'Cluster': 2,
#   'DBPM': 2.4,
#   'FG': 4.9,
#   'FT': 1.8,
#   'FTA': 2.4,
#   'GS': 66,
#   'ORB': 1.6,
#   'STL': 0.7,
#   'STL.': 1.3,
#   'TOV.': 13.7,
#   'VORP': 1.8,
#   'WS': 4.3,
#   'WS.48': 0.10800000000000001,
#   'average.salary': 1525423,
#   'eFG.': 0.474,
#   'fix': 'davidwest'},
#  {'Age': 26,
#   'BLK': 2.2,
#   'BLK.': 5.4,
#   'BPM': 4.1,
#   'Cluster': 8,
#   'DBPM': 3.2,
#   'FG': 4.6,
#   'FT': 2.3,
#   'FTA': 5.7,
#   'GS': 82,
#   'ORB': 4.8,
#   'STL': 1.0,
#   'STL.': 1.5,
#   'TOV.': 12.8,
#   'VORP': 4.3,
#   'WS': 12.8,
#   'WS.48': 0.217,
#   'average.salary': 21904013,
#   'eFG.': 0.711,
#   'fix': 'deandrejordan'},
#  {'Age': 24,
#   'BLK': 1.7,
#   'BLK.': 4.0,
#   'BPM': 4.7,
#   'Cluster': 8,
#   'DBPM': 3.3,
#   'FG': 8.4,
#   'FT': 7.2,
#   'FTA': 9.2,
#   'GS': 59,
#   'ORB': 3.1,
#   'STL': 1.5,
#   'STL.': 2.3,
#   'TOV.': 16.3,
#   'VORP': 3.4,
#   'WS': 6.0,
#   'WS.48': 0.14400000000000002,
#   'average.salary': 16404925,
#   'eFG.': 0.46799999999999997,
#   'fix': 'demarcuscousins'},
#  {'Age': 25,
#   'BLK': 0.2,
#   'BLK.': 0.4,
#   'BPM': -1.6,
#   'Cluster': 6,
#   'DBPM': -1.4,
#   'FG': 6.8,
#   'FT': 6.0,
#   'FTA': 7.2,
#   'GS': 60,
#   'ORB': 0.7,
#   'STL': 1.2,
#   'STL.': 1.8,
#   'TOV.': 10.4,
#   'VORP': 0.2,
#   'WS': 4.0,
#   'WS.48': 0.09,
#   'average.salary': 9500000,
#   'eFG.': 0.426,
#   'fix': 'demarderozan'},
#  {'Age': 28,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': 2.9,
#   'Cluster': 8,
#   'DBPM': 0.5,
#   'FG': 4.5,
#   'FT': 1.8,
#   'FTA': 2.6,
#   'GS': 69,
#   'ORB': 1.4,
#   'STL': 1.3,
#   'STL.': 2.2,
#   'TOV.': 9.3,
#   'VORP': 2.7,
#   'WS': 7.0,
#   'WS.48': 0.154,
#   'average.salary': 14500000,
#   'eFG.': 0.579,
#   'fix': 'demarrecarroll'},
#  {'Age': 30,
#   'BLK': 0.3,
#   'BLK.': 0.6,
#   'BPM': 0.1,
#   'Cluster': 4,
#   'DBPM': -1.2,
#   'FG': 4.4,
#   'FT': 3.0,
#   'FTA': 3.5,
#   'GS': 55,
#   'ORB': 0.4,
#   'STL': 0.9,
#   'STL.': 1.6,
#   'TOV.': 14.9,
#   'VORP': 1.1,
#   'WS': 3.6,
#   'WS.48': 0.083,
#   'average.salary': 5500000,
#   'eFG.': 0.44299999999999995,
#   'fix': 'deronwilliams'},
#  {'Age': 23,
#   'BLK': 1.7,
#   'BLK.': 4.3,
#   'BPM': 2.4,
#   'Cluster': 7,
#   'DBPM': 1.7,
#   'FG': 6.5,
#   'FT': 3.0,
#   'FTA': 4.5,
#   'GS': 74,
#   'ORB': 2.6,
#   'STL': 0.8,
#   'STL.': 1.4,
#   'TOV.': 10.2,
#   'VORP': 2.6,
#   'WS': 8.3,
#   'WS.48': 0.175,
#   'average.salary': 11737500,
#   'eFG.': 0.526,
#   'fix': 'derrickfavors'},
#  {'Age': 26,
#   'BLK': 0.3,
#   'BLK.': 0.8,
#   'BPM': -1.3,
#   'Cluster': 8,
#   'DBPM': -2.3,
#   'FG': 6.6,
#   'FT': 3.0,
#   'FTA': 3.7,
#   'GS': 51,
#   'ORB': 0.7,
#   'STL': 0.7,
#   'STL.': 1.2,
#   'TOV.': 14.9,
#   'VORP': 0.3,
#   'WS': 1.2,
#   'WS.48': 0.038,
#   'average.salary': 18862876,
#   'eFG.': 0.45,
#   'fix': 'derrickrose'},
#  {'Age': 26,
#   'BLK': 0.3,
#   'BLK.': 0.8,
#   'BPM': -1.3,
#   'Cluster': 8,
#   'DBPM': -2.3,
#   'FG': 6.6,
#   'FT': 3.0,
#   'FTA': 3.7,
#   'GS': 51,
#   'ORB': 0.7,
#   'STL': 0.7,
#   'STL.': 1.2,
#   'TOV.': 14.9,
#   'VORP': 0.3,
#   'WS': 1.2,
#   'WS.48': 0.038,
#   'average.salary': 20093064,
#   'eFG.': 0.45,
#   'fix': 'derrickrose'},
#  {'Age': 23,
#   'BLK': 0.1,
#   'BLK.': 0.2,
#   'BPM': -3.2,
#   'Cluster': 3,
#   'DBPM': -2.7,
#   'FG': 2.9,
#   'FT': 1.8,
#   'FTA': 2.6,
#   'GS': 6,
#   'ORB': 0.6,
#   'STL': 0.5,
#   'STL.': 1.2,
#   'TOV.': 8.9,
#   'VORP': -0.5,
#   'WS': 2.1,
#   'WS.48': 0.069,
#   'average.salary': 4499000,
#   'eFG.': 0.498,
#   'fix': 'derrickwilliams'},
#  {'Age': 31,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': 1.2,
#   'Cluster': 3,
#   'DBPM': -0.8,
#   'FG': 2.9,
#   'FT': 1.7,
#   'FTA': 2.1,
#   'GS': 3,
#   'ORB': 0.2,
#   'STL': 1.0,
#   'STL.': 2.3,
#   'TOV.': 12.5,
#   'VORP': 1.3,
#   'WS': 4.2,
#   'WS.48': 0.12,
#   'average.salary': 4140721,
#   'eFG.': 0.509,
#   'fix': 'devinharris'},
#  {'Age': 25,
#   'BLK': 0.8,
#   'BLK.': 4.8,
#   'BPM': -3.3,
#   'Cluster': 1,
#   'DBPM': 0.3,
#   'FG': 1.5,
#   'FT': 0.6,
#   'FTA': 1.1,
#   'GS': 15,
#   'ORB': 2.0,
#   'STL': 0.3,
#   'STL.': 1.0,
#   'TOV.': 21.1,
#   'VORP': -0.3,
#   'WS': 1.7,
#   'WS.48': 0.099,
#   'average.salary': 687919,
#   'eFG.': 0.562,
#   'fix': 'dewaynededmon'},
#  {'Age': 23,
#   'BLK': 0.3,
#   'BLK.': 0.8,
#   'BPM': -3.6,
#   'Cluster': 3,
#   'DBPM': -1.5,
#   'FG': 4.7,
#   'FT': 1.5,
#   'FTA': 2.2,
#   'GS': 23,
#   'ORB': 0.5,
#   'STL': 1.1,
#   'STL.': 2.1,
#   'TOV.': 10.0,
#   'VORP': -0.9,
#   'WS': 1.1,
#   'WS.48': 0.025,
#   'average.salary': 4205318,
#   'eFG.': 0.435,
#   'fix': 'dionwaiters'},
#  {'Age': 36,
#   'BLK': 0.4,
#   'BLK.': 1.2,
#   'BPM': 0.7,
#   'Cluster': 5,
#   'DBPM': -1.0,
#   'FG': 6.3,
#   'FT': 3.3,
#   'FTA': 3.8,
#   'GS': 77,
#   'ORB': 0.6,
#   'STL': 0.5,
#   'STL.': 0.9,
#   'TOV.': 6.5,
#   'VORP': 1.5,
#   'WS': 7.2,
#   'WS.48': 0.152,
#   'average.salary': 8333333,
#   'eFG.': 0.508,
#   'fix': 'dirknowitzki'},
#  {'Age': 27,
#   'BLK': 0.0,
#   'BLK.': 0.1,
#   'BPM': -2.5,
#   'Cluster': 3,
#   'DBPM': -2.7,
#   'FG': 3.1,
#   'FT': 2.2,
#   'FTA': 2.5,
#   'GS': 14,
#   'ORB': 0.2,
#   'STL': 0.6,
#   'STL.': 1.3,
#   'TOV.': 16.4,
#   'VORP': -0.3,
#   'WS': 3.4,
#   'WS.48': 0.083,
#   'average.salary': 3000000,
#   'eFG.': 0.46299999999999997,
#   'fix': 'djaugustin'},
#  {'Age': 27,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -1.4,
#   'Cluster': 1,
#   'DBPM': -1.0,
#   'FG': 2.7,
#   'FT': 1.1,
#   'FTA': 1.5,
#   'GS': 21,
#   'ORB': 0.2,
#   'STL': 0.4,
#   'STL.': 1.1,
#   'TOV.': 14.3,
#   'VORP': 0.2,
#   'WS': 2.0,
#   'WS.48': 0.085,
#   'average.salary': 1015421,
#   'eFG.': 0.466,
#   'fix': 'donaldsloan'},
#  {'Age': 24,
#   'BLK': 0.5,
#   'BLK.': 1.3,
#   'BPM': -0.1,
#   'Cluster': 2,
#   'DBPM': 0.5,
#   'FG': 5.0,
#   'FT': 1.4,
#   'FTA': 2.3,
#   'GS': 62,
#   'ORB': 1.9,
#   'STL': 0.8,
#   'STL.': 1.4,
#   'TOV.': 13.7,
#   'VORP': 1.0,
#   'WS': 4.7,
#   'WS.48': 0.11,
#   'average.salary': 1639061,
#   'eFG.': 0.539,
#   'fix': 'donatasmotiejunas'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 1.3,
#   'BPM': 0.7,
#   'Cluster': 1,
#   'DBPM': 0.6,
#   'FG': 1.5,
#   'FT': 0.7,
#   'FTA': 0.9,
#   'GS': 2,
#   'ORB': 0.3,
#   'STL': 0.4,
#   'STL.': 1.7,
#   'TOV.': 7.9,
#   'VORP': 0.4,
#   'WS': 1.6,
#   'WS.48': 0.128,
#   'average.salary': 17637,
#   'eFG.': 0.48700000000000004,
#   'fix': 'dorellwright'},
#  {'Age': 23,
#   'BLK': 0.0,
#   'BLK.': 0.2,
#   'BPM': -8.0,
#   'Cluster': 2,
#   'DBPM': -3.3,
#   'FG': 1.2,
#   'FT': 0.3,
#   'FTA': 0.4,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.1,
#   'STL.': 0.6,
#   'TOV.': 13.0,
#   'VORP': -0.5,
#   'WS': 0.0,
#   'WS.48': -0.005,
#   'average.salary': 2609109,
#   'eFG.': 0.46299999999999997,
#   'fix': 'dougmcdermott'},
#  {'Age': 24,
#   'BLK': 1.3,
#   'BLK.': 2.9,
#   'BPM': 5.0,
#   'Cluster': 8,
#   'DBPM': 4.0,
#   'FG': 4.3,
#   'FT': 1.7,
#   'FTA': 2.5,
#   'GS': 79,
#   'ORB': 1.4,
#   'STL': 1.6,
#   'STL.': 2.4,
#   'TOV.': 13.5,
#   'VORP': 4.4,
#   'WS': 8.5,
#   'WS.48': 0.163,
#   'average.salary': 16400000,
#   'eFG.': 0.516,
#   'fix': 'draymondgreen'},
#  {'Age': 33,
#   'BLK': 0.2,
#   'BLK.': 0.8,
#   'BPM': -1.6,
#   'Cluster': 3,
#   'DBPM': 0.2,
#   'FG': 2.2,
#   'FT': 0.7,
#   'FTA': 0.9,
#   'GS': 7,
#   'ORB': 1.4,
#   'STL': 0.4,
#   'STL.': 1.2,
#   'TOV.': 8.7,
#   'VORP': 0.1,
#   'WS': 1.7,
#   'WS.48': 0.094,
#   'average.salary': 3423500,
#   'eFG.': 0.44,
#   'fix': 'drewgooden'},
#  {'Age': 29,
#   'BLK': 1.3,
#   'BLK.': 3.4,
#   'BPM': -1.2,
#   'Cluster': 8,
#   'DBPM': 1.2,
#   'FG': 6.1,
#   'FT': 3.5,
#   'FTA': 6.6,
#   'GS': 41,
#   'ORB': 2.7,
#   'STL': 0.7,
#   'STL.': 1.1,
#   'TOV.': 17.5,
#   'VORP': 0.3,
#   'WS': 3.6,
#   'WS.48': 0.14,
#   'average.salary': 21897818,
#   'eFG.': 0.595,
#   'fix': 'dwighthoward'},
#  {'Age': 23,
#   'BLK': 0.2,
#   'BLK.': 2.1,
#   'BPM': -0.9,
#   'Cluster': 1,
#   'DBPM': 0.1,
#   'FG': 1.1,
#   'FT': 0.9,
#   'FTA': 1.1,
#   'GS': 0,
#   'ORB': 0.6,
#   'STL': 0.3,
#   'STL.': 1.9,
#   'TOV.': 11.9,
#   'VORP': 0.1,
#   'WS': 0.6,
#   'WS.48': 0.122,
#   'average.salary': 676198,
#   'eFG.': 0.485,
#   'fix': 'dwightpowell'},
#  {'Age': 33,
#   'BLK': 0.3,
#   'BLK.': 0.9,
#   'BPM': 1.2,
#   'Cluster': 8,
#   'DBPM': -1.2,
#   'FG': 8.2,
#   'FT': 4.6,
#   'FTA': 6.0,
#   'GS': 62,
#   'ORB': 0.9,
#   'STL': 1.2,
#   'STL.': 2.0,
#   'TOV.': 14.4,
#   'VORP': 1.6,
#   'WS': 3.5,
#   'WS.48': 0.086,
#   'average.salary': 20000000,
#   'eFG.': 0.483,
#   'fix': 'dwyanewade'},
#  {'Age': 25,
#   'BLK': 1.2,
#   'BLK.': 4.3,
#   'BPM': 3.0,
#   'Cluster': 4,
#   'DBPM': 1.9,
#   'FG': 3.6,
#   'FT': 1.2,
#   'FTA': 2.4,
#   'GS': 24,
#   'ORB': 2.9,
#   'STL': 0.6,
#   'STL.': 1.4,
#   'TOV.': 9.5,
#   'VORP': 2.3,
#   'WS': 6.3,
#   'WS.48': 0.16399999999999998,
#   'average.salary': 6666667,
#   'eFG.': 0.601,
#   'fix': 'eddavis'},
#  {'Age': 20,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': -0.7,
#   'Cluster': 2,
#   'DBPM': 0.8,
#   'FG': 3.7,
#   'FT': 1.4,
#   'FTA': 2.6,
#   'GS': 63,
#   'ORB': 1.3,
#   'STL': 1.7,
#   'STL.': 2.9,
#   'TOV.': 20.2,
#   'VORP': 0.8,
#   'WS': 2.3,
#   'WS.48': 0.044000000000000004,
#   'average.salary': 2712375,
#   'eFG.': 0.433,
#   'fix': 'elfridpayton'},
#  {'Age': 25,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -4.6,
#   'Cluster': 1,
#   'DBPM': -2.9,
#   'FG': 1.1,
#   'FT': 0.1,
#   'FTA': 0.3,
#   'GS': 0,
#   'ORB': 0.0,
#   'STL': 0.3,
#   'STL.': 1.8,
#   'TOV.': 9.4,
#   'VORP': -0.1,
#   'WS': 0.1,
#   'WS.48': 0.039,
#   'average.salary': 5773,
#   'eFG.': 0.486,
#   'fix': 'elliotwilliams'},
#  {'Age': 35,
#   'BLK': 0.7,
#   'BLK.': 4.3,
#   'BPM': -1.4,
#   'Cluster': 1,
#   'DBPM': 3.1,
#   'FG': 1.2,
#   'FT': 0.3,
#   'FTA': 0.6,
#   'GS': 4,
#   'ORB': 0.8,
#   'STL': 0.5,
#   'STL.': 1.8,
#   'TOV.': 14.6,
#   'VORP': 0.1,
#   'WS': 0.7,
#   'WS.48': 0.07,
#   'average.salary': 890693,
#   'eFG.': 0.442,
#   'fix': 'eltonbrand'},
#  {'Age': 22,
#   'BLK': 0.4,
#   'BLK.': 1.1,
#   'BPM': -2.1,
#   'Cluster': 8,
#   'DBPM': -2.3,
#   'FG': 6.4,
#   'FT': 2.4,
#   'FTA': 3.1,
#   'GS': 74,
#   'ORB': 3.7,
#   'STL': 0.5,
#   'STL.': 0.9,
#   'TOV.': 12.3,
#   'VORP': -0.1,
#   'WS': 6.4,
#   'WS.48': 0.145,
#   'average.salary': 17515007,
#   'eFG.': 0.528,
#   'fix': 'eneskanter'},
#  {'Age': 25,
#   'BLK': 0.6,
#   'BLK.': 1.2,
#   'BPM': 2.6,
#   'Cluster': 8,
#   'DBPM': 0.9,
#   'FG': 5.8,
#   'FT': 4.4,
#   'FTA': 5.4,
#   'GS': 81,
#   'ORB': 0.9,
#   'STL': 1.6,
#   'STL.': 2.3,
#   'TOV.': 18.1,
#   'VORP': 3.3,
#   'WS': 7.0,
#   'WS.48': 0.11900000000000001,
#   'average.salary': 14000000,
#   'eFG.': 0.489,
#   'fix': 'ericbledsoe'},
#  {'Age': 26,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': -0.6,
#   'Cluster': 8,
#   'DBPM': -2.0,
#   'FG': 4.7,
#   'FT': 1.8,
#   'FTA': 2.2,
#   'GS': 60,
#   'ORB': 0.5,
#   'STL': 0.8,
#   'STL.': 1.3,
#   'TOV.': 14.0,
#   'VORP': 0.7,
#   'WS': 2.9,
#   'WS.48': 0.069,
#   'average.salary': 14591391,
#   'eFG.': 0.512,
#   'fix': 'ericgordon'},
#  {'Age': 23,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -5.4,
#   'Cluster': 1,
#   'DBPM': -2.7,
#   'FG': 1.4,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 1,
#   'ORB': 0.2,
#   'STL': 0.3,
#   'STL.': 1.5,
#   'TOV.': 7.7,
#   'VORP': -0.3,
#   'WS': 0.0,
#   'WS.48': 0.0,
#   'average.salary': 4971,
#   'eFG.': 0.42,
#   'fix': 'erickgreen'},
#  {'Age': 23,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -5.4,
#   'Cluster': 1,
#   'DBPM': -2.7,
#   'FG': 1.4,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 1,
#   'ORB': 0.2,
#   'STL': 0.3,
#   'STL.': 1.5,
#   'TOV.': 7.7,
#   'VORP': -0.3,
#   'WS': 0.0,
#   'WS.48': 0.0,
#   'average.salary': 4971,
#   'eFG.': 0.42,
#   'fix': 'erickgreen'},
#  {'Age': 23,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -4.5,
#   'Cluster': 1,
#   'DBPM': -10.2,
#   'FG': 0.3,
#   'FT': 0.0,
#   'FTA': 0.0,
#   'GS': 0,
#   'ORB': 0.0,
#   'STL': 0.0,
#   'STL.': 0.0,
#   'TOV.': 0.0,
#   'VORP': 0.0,
#   'WS': 0.0,
#   'WS.48': 0.431,
#   'average.salary': 845059,
#   'eFG.': 1.0,
#   'fix': 'ericmoreland'},
#  {'Age': 27,
#   'BLK': 0.3,
#   'BLK.': 1.2,
#   'BPM': -0.2,
#   'Cluster': 2,
#   'DBPM': -1.4,
#   'FG': 4.5,
#   'FT': 1.2,
#   'FTA': 1.8,
#   'GS': 36,
#   'ORB': 1.4,
#   'STL': 0.6,
#   'STL.': 1.4,
#   'TOV.': 6.9,
#   'VORP': 0.6,
#   'WS': 4.0,
#   'WS.48': 0.146,
#   'average.salary': 2648824,
#   'eFG.': 0.539,
#   'fix': 'ersanilyasova'},
#  {'Age': 27,
#   'BLK': 0.3,
#   'BLK.': 1.2,
#   'BPM': -0.2,
#   'Cluster': 5,
#   'DBPM': -1.4,
#   'FG': 4.5,
#   'FT': 1.2,
#   'FTA': 1.8,
#   'GS': 36,
#   'ORB': 1.4,
#   'STL': 0.6,
#   'STL.': 1.4,
#   'TOV.': 6.9,
#   'VORP': 0.6,
#   'WS': 4.0,
#   'WS.48': 0.146,
#   'average.salary': 8000000,
#   'eFG.': 0.539,
#   'fix': 'ersanilyasova'},
#  {'Age': 25,
#   'BLK': 0.1,
#   'BLK.': 0.9,
#   'BPM': -2.5,
#   'Cluster': 1,
#   'DBPM': -0.6,
#   'FG': 1.1,
#   'FT': 0.2,
#   'FTA': 0.4,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.4,
#   'STL.': 2.1,
#   'TOV.': 8.7,
#   'VORP': -0.1,
#   'WS': 0.8,
#   'WS.48': 0.08,
#   'average.salary': 981792,
#   'eFG.': 0.493,
#   'fix': 'etwaunmoore'},
#  {'Age': 22,
#   'BLK': 0.0,
#   'BLK.': 0.1,
#   'BPM': -2.1,
#   'Cluster': 2,
#   'DBPM': -2.3,
#   'FG': 4.4,
#   'FT': 1.8,
#   'FTA': 2.5,
#   'GS': 32,
#   'ORB': 0.5,
#   'STL': 0.7,
#   'STL.': 1.2,
#   'TOV.': 11.4,
#   'VORP': -0.1,
#   'WS': 2.1,
#   'WS.48': 0.059000000000000004,
#   'average.salary': 1639061,
#   'eFG.': 0.514,
#   'fix': 'evanfournier'},
#  {'Age': 26,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': -1.0,
#   'Cluster': 3,
#   'DBPM': 1.3,
#   'FG': 3.9,
#   'FT': 1.3,
#   'FTA': 1.7,
#   'GS': 57,
#   'ORB': 0.5,
#   'STL': 1.0,
#   'STL.': 1.8,
#   'TOV.': 19.7,
#   'VORP': 0.6,
#   'WS': 2.5,
#   'WS.48': 0.054000000000000006,
#   'average.salary': 3351755,
#   'eFG.': 0.451,
#   'fix': 'evanturner'},
#  {'Age': 25,
#   'BLK': 0.9,
#   'BLK.': 6.2,
#   'BPM': -1.8,
#   'Cluster': 1,
#   'DBPM': 1.2,
#   'FG': 1.7,
#   'FT': 1.1,
#   'FTA': 1.7,
#   'GS': 7,
#   'ORB': 1.3,
#   'STL': 0.2,
#   'STL.': 0.7,
#   'TOV.': 15.6,
#   'VORP': 0.0,
#   'WS': 1.7,
#   'WS.48': 0.159,
#   'average.salary': 1302377,
#   'eFG.': 0.547,
#   'fix': 'festusezeli'},
#  {'Age': 28,
#   'BLK': 0.2,
#   'BLK.': 1.0,
#   'BPM': 0.8,
#   'Cluster': 1,
#   'DBPM': 1.4,
#   'FG': 1.3,
#   'FT': 0.7,
#   'FTA': 0.9,
#   'GS': 18,
#   'ORB': 0.5,
#   'STL': 0.8,
#   'STL.': 2.9,
#   'TOV.': 15.1,
#   'VORP': 0.5,
#   'WS': 1.5,
#   'WS.48': 0.1,
#   'average.salary': 1040843,
#   'eFG.': 0.49700000000000005,
#   'fix': 'garretttemple'},
#  {'Age': 20,
#   'BLK': 0.1,
#   'BLK.': 0.8,
#   'BPM': -4.3,
#   'Cluster': 2,
#   'DBPM': -0.1,
#   'FG': 1.2,
#   'FT': 0.6,
#   'FTA': 0.9,
#   'GS': 6,
#   'ORB': 0.4,
#   'STL': 0.7,
#   'STL.': 2.7,
#   'TOV.': 13.8,
#   'VORP': -0.4,
#   'WS': -0.7,
#   'WS.48': -0.046,
#   'average.salary': 1828154,
#   'eFG.': 0.353,
#   'fix': 'garyharris'},
#  {'Age': 28,
#   'BLK': 0.3,
#   'BLK.': 0.9,
#   'BPM': 5.6,
#   'Cluster': 5,
#   'DBPM': 0.2,
#   'FG': 5.9,
#   'FT': 2.6,
#   'FTA': 3.3,
#   'GS': 36,
#   'ORB': 0.6,
#   'STL': 1.0,
#   'STL.': 1.8,
#   'TOV.': 10.3,
#   'VORP': 2.4,
#   'WS': 5.4,
#   'WS.48': 0.203,
#   'average.salary': 8000000,
#   'eFG.': 0.541,
#   'fix': 'georgehill'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 0.6,
#   'BPM': -2.4,
#   'Cluster': 1,
#   'DBPM': -3.3,
#   'FG': 4.4,
#   'FT': 1.3,
#   'FTA': 1.6,
#   'GS': 4,
#   'ORB': 0.4,
#   'STL': 0.6,
#   'STL.': 1.4,
#   'TOV.': 11.1,
#   'VORP': -0.2,
#   'WS': 1.9,
#   'WS.48': 0.065,
#   'average.salary': 1356146,
#   'eFG.': 0.504,
#   'fix': 'geraldgreen'},
#  {'Age': 27,
#   'BLK': 0.3,
#   'BLK.': 0.7,
#   'BPM': -1.5,
#   'Cluster': 4,
#   'DBPM': -0.4,
#   'FG': 4.6,
#   'FT': 2.3,
#   'FTA': 2.7,
#   'GS': 72,
#   'ORB': 0.5,
#   'STL': 0.6,
#   'STL.': 1.1,
#   'TOV.': 10.5,
#   'VORP': 0.3,
#   'WS': 3.6,
#   'WS.48': 0.07400000000000001,
#   'average.salary': 6000000,
#   'eFG.': 0.46299999999999997,
#   'fix': 'geraldhenderson'},
#  {'Age': 20,
#   'BLK': 1.0,
#   'BLK.': 2.8,
#   'BPM': 0.5,
#   'Cluster': 3,
#   'DBPM': 2.1,
#   'FG': 4.7,
#   'FT': 3.2,
#   'FTA': 4.3,
#   'GS': 71,
#   'ORB': 1.2,
#   'STL': 0.9,
#   'STL.': 1.5,
#   'TOV.': 15.6,
#   'VORP': 1.6,
#   'WS': 6.2,
#   'WS.48': 0.11699999999999999,
#   'average.salary': 2871714,
#   'eFG.': 0.496,
#   'fix': 'giannisantetokounmpo'},
#  {'Age': 28,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': 1.1,
#   'Cluster': 8,
#   'DBPM': -1.4,
#   'FG': 6.4,
#   'FT': 2.3,
#   'FTA': 3.0,
#   'GS': 78,
#   'ORB': 1.0,
#   'STL': 1.0,
#   'STL.': 1.5,
#   'TOV.': 13.5,
#   'VORP': 2.1,
#   'WS': 6.8,
#   'WS.48': 0.12300000000000001,
#   'average.salary': 17000450,
#   'eFG.': 0.546,
#   'fix': 'gorandragic'},
#  {'Age': 24,
#   'BLK': 0.4,
#   'BLK.': 0.9,
#   'BPM': 3.4,
#   'Cluster': 8,
#   'DBPM': 0.1,
#   'FG': 6.4,
#   'FT': 4.9,
#   'FTA': 6.1,
#   'GS': 76,
#   'ORB': 0.7,
#   'STL': 1.4,
#   'STL.': 2.2,
#   'TOV.': 13.8,
#   'VORP': 3.6,
#   'WS': 8.7,
#   'WS.48': 0.159,
#   'average.salary': 15741355,
#   'eFG.': 0.5,
#   'fix': 'gordonhayward'},
#  {'Age': 25,
#   'BLK': 1.7,
#   'BLK.': 4.5,
#   'BPM': 2.5,
#   'Cluster': 2,
#   'DBPM': 2.4,
#   'FG': 3.5,
#   'FT': 2.6,
#   'FTA': 3.3,
#   'GS': 49,
#   'ORB': 3.1,
#   'STL': 1.0,
#   'STL.': 1.6,
#   'TOV.': 16.9,
#   'VORP': 2.5,
#   'WS': 4.9,
#   'WS.48': 0.10800000000000001,
#   'average.salary': 1647336,
#   'eFG.': 0.507,
#   'fix': 'gorguidieng'},
#  {'Age': 24,
#   'BLK': 0.5,
#   'BLK.': 1.3,
#   'BPM': 1.9,
#   'Cluster': 8,
#   'DBPM': 1.3,
#   'FG': 6.1,
#   'FT': 3.7,
#   'FTA': 4.9,
#   'GS': 57,
#   'ORB': 3.3,
#   'STL': 1.1,
#   'STL.': 1.9,
#   'TOV.': 13.0,
#   'VORP': 2.1,
#   'WS': 6.8,
#   'WS.48': 0.153,
#   'average.salary': 17145838,
#   'eFG.': 0.496,
#   'fix': 'gregmonroe'},
#  {'Age': 24,
#   'BLK': 0.3,
#   'BLK.': 2.5,
#   'BPM': -1.0,
#   'Cluster': 1,
#   'DBPM': 1.0,
#   'FG': 0.7,
#   'FT': 0.5,
#   'FTA': 0.9,
#   'GS': 2,
#   'ORB': 0.6,
#   'STL': 0.2,
#   'STL.': 1.0,
#   'TOV.': 14.3,
#   'VORP': 0.1,
#   'WS': 0.8,
#   'WS.48': 0.10800000000000001,
#   'average.salary': 635265,
#   'eFG.': 0.612,
#   'fix': 'gregsmith'},
#  {'Age': 24,
#   'BLK': 0.3,
#   'BLK.': 2.5,
#   'BPM': -1.0,
#   'Cluster': 1,
#   'DBPM': 1.0,
#   'FG': 0.7,
#   'FT': 0.5,
#   'FTA': 0.9,
#   'GS': 2,
#   'ORB': 0.6,
#   'STL': 0.2,
#   'STL.': 1.0,
#   'TOV.': 14.3,
#   'VORP': 0.1,
#   'WS': 0.8,
#   'WS.48': 0.10800000000000001,
#   'average.salary': 5973,
#   'eFG.': 0.612,
#   'fix': 'gregsmith'},
#  {'Age': 28,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -1.1,
#   'Cluster': 4,
#   'DBPM': -2.1,
#   'FG': 3.6,
#   'FT': 0.6,
#   'FTA': 0.8,
#   'GS': 29,
#   'ORB': 0.3,
#   'STL': 0.6,
#   'STL.': 1.2,
#   'TOV.': 13.6,
#   'VORP': 0.4,
#   'WS': 2.8,
#   'WS.48': 0.066,
#   'average.salary': 6500000,
#   'eFG.': 0.5,
#   'fix': 'greivisvasquez'},
#  {'Age': 22,
#   'BLK': 0.2,
#   'BLK.': 0.6,
#   'BPM': 1.1,
#   'Cluster': 2,
#   'DBPM': 0.6,
#   'FG': 3.9,
#   'FT': 1.3,
#   'FTA': 1.8,
#   'GS': 82,
#   'ORB': 1.4,
#   'STL': 0.7,
#   'STL.': 1.3,
#   'TOV.': 9.0,
#   'VORP': 1.8,
#   'WS': 6.7,
#   'WS.48': 0.139,
#   'average.salary': 2192970,
#   'eFG.': 0.5479999999999999,
#   'fix': 'harrisonbarnes'},
#  {'Age': 25,
#   'BLK': 2.6,
#   'BLK.': 9.2,
#   'BPM': -0.9,
#   'Cluster': 1,
#   'DBPM': 0.7,
#   'FG': 5.1,
#   'FT': 1.6,
#   'FTA': 3.3,
#   'GS': 32,
#   'ORB': 3.0,
#   'STL': 0.6,
#   'STL.': 1.2,
#   'TOV.': 11.3,
#   'VORP': 0.3,
#   'WS': 5.3,
#   'WS.48': 0.221,
#   'average.salary': 875615,
#   'eFG.': 0.628,
#   'fix': 'hassanwhiteside'},
#  {'Age': 24,
#   'BLK': 0.4,
#   'BLK.': 1.7,
#   'BPM': -3.4,
#   'Cluster': 1,
#   'DBPM': -0.1,
#   'FG': 3.3,
#   'FT': 1.5,
#   'FTA': 1.9,
#   'GS': 32,
#   'ORB': 1.7,
#   'STL': 0.5,
#   'STL.': 1.4,
#   'TOV.': 15.0,
#   'VORP': -0.5,
#   'WS': 2.1,
#   'WS.48': 0.07200000000000001,
#   'average.salary': 46181,
#   'eFG.': 0.478,
#   'fix': 'henrysims'},
#  {'Age': 24,
#   'BLK': 0.4,
#   'BLK.': 1.7,
#   'BPM': -3.4,
#   'Cluster': 1,
#   'DBPM': -0.1,
#   'FG': 3.3,
#   'FT': 1.5,
#   'FTA': 1.9,
#   'GS': 32,
#   'ORB': 1.7,
#   'STL': 0.5,
#   'STL.': 1.4,
#   'TOV.': 15.0,
#   'VORP': -0.5,
#   'WS': 2.1,
#   'WS.48': 0.07200000000000001,
#   'average.salary': 5773,
#   'eFG.': 0.478,
#   'fix': 'henrysims'},
#  {'Age': 24,
#   'BLK': 0.4,
#   'BLK.': 1.7,
#   'BPM': -3.4,
#   'Cluster': 1,
#   'DBPM': -0.1,
#   'FG': 3.3,
#   'FT': 1.5,
#   'FTA': 1.9,
#   'GS': 32,
#   'ORB': 1.7,
#   'STL': 0.5,
#   'STL.': 1.4,
#   'TOV.': 15.0,
#   'VORP': -0.5,
#   'WS': 2.1,
#   'WS.48': 0.07200000000000001,
#   'average.salary': 5773,
#   'eFG.': 0.478,
#   'fix': 'henrysims'},
#  {'Age': 23,
#   'BLK': 0.4,
#   'BLK.': 1.2,
#   'BPM': -2.1,
#   'Cluster': 1,
#   'DBPM': -0.9,
#   'FG': 3.2,
#   'FT': 0.9,
#   'FTA': 1.3,
#   'GS': 23,
#   'ORB': 0.7,
#   'STL': 0.8,
#   'STL.': 1.6,
#   'TOV.': 10.2,
#   'VORP': 0.0,
#   'WS': 2.6,
#   'WS.48': 0.07,
#   'average.salary': 817409,
#   'eFG.': 0.518,
#   'fix': 'hollisthompson'},
#  {'Age': 23,
#   'BLK': 0.1,
#   'BLK.': 1.2,
#   'BPM': -2.8,
#   'Cluster': 1,
#   'DBPM': -0.8,
#   'FG': 0.6,
#   'FT': 0.3,
#   'FTA': 0.3,
#   'GS': 0,
#   'ORB': 0.1,
#   'STL': 0.3,
#   'STL.': 2.4,
#   'TOV.': 13.2,
#   'VORP': 0.0,
#   'WS': 0.2,
#   'WS.48': 0.05,
#   'average.salary': 947276,
#   'eFG.': 0.436,
#   'fix': 'ianclark'},
#  {'Age': 28,
#   'BLK': 0.8,
#   'BLK.': 3.1,
#   'BPM': -1.2,
#   'Cluster': 3,
#   'DBPM': 2.6,
#   'FG': 1.9,
#   'FT': 0.5,
#   'FTA': 1.7,
#   'GS': 6,
#   'ORB': 1.7,
#   'STL': 0.5,
#   'STL.': 1.3,
#   'TOV.': 18.7,
#   'VORP': 0.2,
#   'WS': 2.1,
#   'WS.48': 0.09,
#   'average.salary': 4000000,
#   'eFG.': 0.552,
#   'fix': 'ianmahinmi'},
#  {'Age': 24,
#   'BLK': 0.3,
#   'BLK.': 0.8,
#   'BPM': -0.4,
#   'Cluster': 6,
#   'DBPM': 0.3,
#   'FG': 3.1,
#   'FT': 0.7,
#   'FTA': 1.0,
#   'GS': 25,
#   'ORB': 0.9,
#   'STL': 1.3,
#   'STL.': 2.7,
#   'TOV.': 15.4,
#   'VORP': 0.6,
#   'WS': 1.5,
#   'WS.48': 0.047,
#   'average.salary': 10000000,
#   'eFG.': 0.48100000000000004,
#   'fix': 'imanshumpert'},
#  {'Age': 23,
#   'BLK': 0.1,
#   'BLK.': 0.3,
#   'BPM': -2.2,
#   'Cluster': 1,
#   'DBPM': -2.9,
#   'FG': 3.1,
#   'FT': 1.0,
#   'FTA': 1.3,
#   'GS': 21,
#   'ORB': 0.4,
#   'STL': 0.6,
#   'STL.': 1.5,
#   'TOV.': 13.3,
#   'VORP': -0.1,
#   'WS': 1.4,
#   'WS.48': 0.07200000000000001,
#   'average.salary': 778091,
#   'eFG.': 0.507,
#   'fix': 'isaiahcanaan'},
#  {'Age': 25,
#   'BLK': 0.1,
#   'BLK.': 0.2,
#   'BPM': 1.8,
#   'Cluster': 4,
#   'DBPM': -2.8,
#   'FG': 5.0,
#   'FT': 4.5,
#   'FTA': 5.2,
#   'GS': 1,
#   'ORB': 0.5,
#   'STL': 0.9,
#   'STL.': 1.6,
#   'TOV.': 13.1,
#   'VORP': 1.6,
#   'WS': 6.1,
# ...
#   'average.salary': 5663088,
#   'eFG.': 0.45899999999999996,
#   'fix': 'spencerhawes'},
#  {'Age': 26,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': 9.9,
#   'Cluster': 6,
#   'DBPM': 0.3,
#   'FG': 8.2,
#   'FT': 3.9,
#   'FTA': 4.2,
#   'GS': 80,
#   'ORB': 0.7,
#   'STL': 2.0,
#   'STL.': 3.0,
#   'TOV.': 14.3,
#   'VORP': 7.9,
#   'WS': 15.7,
#   'WS.48': 0.28800000000000003,
#   'average.salary': 11000000,
#   'eFG.': 0.594,
#   'fix': 'stephencurry'},
#  {'Age': 34,
#   'BLK': 0.1,
#   'BLK.': 0.2,
#   'BPM': -2.1,
#   'Cluster': 2,
#   'DBPM': -0.9,
#   'FG': 1.5,
#   'FT': 0.4,
#   'FTA': 0.5,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.5,
#   'STL.': 1.4,
#   'TOV.': 23.2,
#   'VORP': 0.0,
#   'WS': 2.1,
#   'WS.48': 0.066,
#   'average.salary': 2123733,
#   'eFG.': 0.491,
#   'fix': 'steveblake'},
#  {'Age': 21,
#   'BLK': 1.2,
#   'BLK.': 3.8,
#   'BPM': 0.4,
#   'Cluster': 2,
#   'DBPM': 1.8,
#   'FG': 3.1,
#   'FT': 1.5,
#   'FTA': 2.9,
#   'GS': 67,
#   'ORB': 2.8,
#   'STL': 0.5,
#   'STL.': 1.1,
#   'TOV.': 16.8,
#   'VORP': 1.1,
#   'WS': 4.1,
#   'WS.48': 0.111,
#   'average.salary': 2423849,
#   'eFG.': 0.544,
#   'fix': 'stevenadams'},
#  {'Age': 31,
#   'BLK': 0.1,
#   'BLK.': 0.8,
#   'BPM': -3.4,
#   'Cluster': 1,
#   'DBPM': -3.2,
#   'FG': 0.6,
#   'FT': 0.0,
#   'FTA': 0.1,
#   'GS': 0,
#   'ORB': 0.1,
#   'STL': 0.0,
#   'STL.': 0.0,
#   'TOV.': 8.1,
#   'VORP': -0.1,
#   'WS': 0.3,
#   'WS.48': 0.075,
#   'average.salary': 424903,
#   'eFG.': 0.563,
#   'fix': 'stevenovak'},
#  {'Age': 29,
#   'BLK': 1.2,
#   'BLK.': 3.2,
#   'BPM': 0.6,
#   'Cluster': 5,
#   'DBPM': 1.1,
#   'FG': 4.1,
#   'FT': 2.1,
#   'FTA': 3.0,
#   'GS': 17,
#   'ORB': 2.6,
#   'STL': 0.6,
#   'STL.': 1.1,
#   'TOV.': 11.6,
#   'VORP': 1.1,
#   'WS': 4.8,
#   'WS.48': 0.13699999999999998,
#   'average.salary': 8250000,
#   'eFG.': 0.502,
#   'fix': 'tajgibson'},
#  {'Age': 23,
#   'BLK': 0.4,
#   'BLK.': 1.6,
#   'BPM': -1.6,
#   'Cluster': 1,
#   'DBPM': -0.6,
#   'FG': 2.5,
#   'FT': 1.0,
#   'FTA': 1.9,
#   'GS': 39,
#   'ORB': 2.3,
#   'STL': 0.3,
#   'STL.': 0.8,
#   'TOV.': 12.9,
#   'VORP': 0.1,
#   'WS': 3.1,
#   'WS.48': 0.124,
#   'average.salary': 676198,
#   'eFG.': 0.575,
#   'fix': 'tarikblack'},
#  {'Age': 34,
#   'BLK': 0.3,
#   'BLK.': 0.9,
#   'BPM': -1.3,
#   'Cluster': 2,
#   'DBPM': 0.1,
#   'FG': 3.1,
#   'FT': 0.8,
#   'FTA': 1.1,
#   'GS': 16,
#   'ORB': 0.9,
#   'STL': 0.5,
#   'STL.': 1.1,
#   'TOV.': 7.5,
#   'VORP': 0.2,
#   'WS': 2.5,
#   'WS.48': 0.086,
#   'average.salary': 1499187,
#   'eFG.': 0.479,
#   'fix': 'tayshaunprince'},
#  {'Age': 23,
#   'BLK': 1.8,
#   'BLK.': 5.2,
#   'BPM': 1.3,
#   'Cluster': 2,
#   'DBPM': 1.9,
#   'FG': 4.8,
#   'FT': 1.7,
#   'FTA': 2.8,
#   'GS': 24,
#   'ORB': 2.4,
#   'STL': 0.5,
#   'STL.': 1.0,
#   'TOV.': 9.8,
#   'VORP': 0.7,
#   'WS': 3.0,
#   'WS.48': 0.16,
#   'average.salary': 1786262,
#   'eFG.': 0.55,
#   'fix': 'terrencejones'},
#  {'Age': 23,
#   'BLK': 0.3,
#   'BLK.': 1.0,
#   'BPM': -1.6,
#   'Cluster': 3,
#   'DBPM': -1.8,
#   'FG': 3.8,
#   'FT': 0.5,
#   'FTA': 0.7,
#   'GS': 61,
#   'ORB': 0.4,
#   'STL': 0.6,
#   'STL.': 1.3,
#   'TOV.': 8.1,
#   'VORP': 0.2,
#   'WS': 2.4,
#   'WS.48': 0.054000000000000006,
#   'average.salary': 2897459,
#   'eFG.': 0.507,
#   'fix': 'terrenceross'},
#  {'Age': 30,
#   'BLK': 0.4,
#   'BLK.': 1.8,
#   'BPM': 1.3,
#   'Cluster': 3,
#   'DBPM': 2.5,
#   'FG': 2.0,
#   'FT': 0.9,
#   'FTA': 1.1,
#   'GS': 7,
#   'ORB': 1.0,
#   'STL': 1.0,
#   'STL.': 2.8,
#   'TOV.': 12.2,
#   'VORP': 0.8,
#   'WS': 2.5,
#   'WS.48': 0.121,
#   'average.salary': 4000000,
#   'eFG.': 0.46799999999999997,
#   'fix': 'thabosefolosha'},
#  {'Age': 26,
#   'BLK': 0.3,
#   'BLK.': 0.8,
#   'BPM': -0.1,
#   'Cluster': 8,
#   'DBPM': -0.3,
#   'FG': 5.9,
#   'FT': 1.7,
#   'FTA': 2.6,
#   'GS': 68,
#   'ORB': 1.7,
#   'STL': 1.6,
#   'STL.': 2.6,
#   'TOV.': 10.0,
#   'VORP': 1.2,
#   'WS': 3.1,
#   'WS.48': 0.061,
#   'average.salary': 13500000,
#   'eFG.': 0.486,
#   'fix': 'thaddeusyoung'},
#  {'Age': 23,
#   'BLK': 0.4,
#   'BLK.': 1.9,
#   'BPM': -2.7,
#   'Cluster': 1,
#   'DBPM': 1.1,
#   'FG': 2.3,
#   'FT': 1.0,
#   'FTA': 2.0,
#   'GS': 4,
#   'ORB': 1.8,
#   'STL': 0.6,
#   'STL.': 2.0,
#   'TOV.': 16.1,
#   'VORP': -0.1,
#   'WS': 1.5,
#   'WS.48': 0.08900000000000001,
#   'average.salary': 1016155,
#   'eFG.': 0.485,
#   'fix': 'thomasrobinson'},
#  {'Age': 30,
#   'BLK': 0.7,
#   'BLK.': 2.7,
#   'BPM': 3.3,
#   'Cluster': 5,
#   'DBPM': 2.4,
#   'FG': 3.3,
#   'FT': 1.7,
#   'FTA': 2.3,
#   'GS': 35,
#   'ORB': 1.8,
#   'STL': 0.7,
#   'STL.': 1.7,
#   'TOV.': 14.4,
#   'VORP': 1.4,
#   'WS': 4.0,
#   'WS.48': 0.18899999999999997,
#   'average.salary': 9000000,
#   'eFG.': 0.5579999999999999,
#   'fix': 'tiagosplitter'},
#  {'Age': 30,
#   'BLK': 0.7,
#   'BLK.': 2.7,
#   'BPM': 3.3,
#   'Cluster': 3,
#   'DBPM': 2.4,
#   'FG': 3.3,
#   'FT': 1.7,
#   'FTA': 2.3,
#   'GS': 35,
#   'ORB': 1.8,
#   'STL': 0.7,
#   'STL.': 1.7,
#   'TOV.': 14.4,
#   'VORP': 1.4,
#   'WS': 4.0,
#   'WS.48': 0.18899999999999997,
#   'average.salary': 3000000,
#   'eFG.': 0.5579999999999999,
#   'fix': 'tiagosplitter'},
#  {'Age': 38,
#   'BLK': 2.0,
#   'BLK.': 5.1,
#   'BPM': 5.5,
#   'Cluster': 4,
#   'DBPM': 4.7,
#   'FG': 5.4,
#   'FT': 3.0,
#   'FTA': 4.0,
#   'GS': 77,
#   'ORB': 2.2,
#   'STL': 0.8,
#   'STL.': 1.4,
#   'TOV.': 12.1,
#   'VORP': 4.2,
#   'WS': 9.6,
#   'WS.48': 0.207,
#   'average.salary': 5425000,
#   'eFG.': 0.513,
#   'fix': 'timduncan'},
#  {'Age': 24,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -7.3,
#   'Cluster': 1,
#   'DBPM': -2.4,
#   'FG': 1.9,
#   'FT': 0.9,
#   'FTA': 1.9,
#   'GS': 3,
#   'ORB': 0.5,
#   'STL': 0.7,
#   'STL.': 1.7,
#   'TOV.': 26.2,
#   'VORP': -0.3,
#   'WS': -0.1,
#   'WS.48': -0.017,
#   'average.salary': 4971,
#   'eFG.': 0.385,
#   'fix': 'timfrazier'},
#  {'Age': 24,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -7.3,
#   'Cluster': 1,
#   'DBPM': -2.4,
#   'FG': 1.9,
#   'FT': 0.9,
#   'FTA': 1.9,
#   'GS': 3,
#   'ORB': 0.5,
#   'STL': 0.7,
#   'STL.': 1.7,
#   'TOV.': 26.2,
#   'VORP': -0.3,
#   'WS': -0.1,
#   'WS.48': -0.017,
#   'average.salary': 24855,
#   'eFG.': 0.385,
#   'fix': 'timfrazier'},
#  {'Age': 22,
#   'BLK': 0.2,
#   'BLK.': 0.7,
#   'BPM': -4.1,
#   'Cluster': 2,
#   'DBPM': -4.2,
#   'FG': 4.0,
#   'FT': 1.8,
#   'FTA': 2.2,
#   'GS': 30,
#   'ORB': 0.2,
#   'STL': 0.3,
#   'STL.': 0.6,
#   'TOV.': 9.5,
#   'VORP': -0.9,
#   'WS': 0.8,
#   'WS.48': 0.023,
#   'average.salary': 1508381,
#   'eFG.': 0.474,
#   'fix': 'timhardaway'},
#  {'Age': 28,
#   'BLK': 1.2,
#   'BLK.': 3.7,
#   'BPM': -0.4,
#   'Cluster': 3,
#   'DBPM': 0.8,
#   'FG': 3.9,
#   'FT': 1.9,
#   'FTA': 2.7,
#   'GS': 80,
#   'ORB': 2.5,
#   'STL': 0.4,
#   'STL.': 0.8,
#   'TOV.': 14.9,
#   'VORP': 0.8,
#   'WS': 5.7,
#   'WS.48': 0.133,
#   'average.salary': 4666667,
#   'eFG.': 0.557,
#   'fix': 'timofeymozgov'},
#  {'Age': 21,
#   'BLK': 0.2,
#   'BLK.': 1.1,
#   'BPM': -2.1,
#   'Cluster': 2,
#   'DBPM': -1.1,
#   'FG': 2.8,
#   'FT': 0.4,
#   'FTA': 0.5,
#   'GS': 1,
#   'ORB': 1.0,
#   'STL': 0.5,
#   'STL.': 1.5,
#   'TOV.': 10.8,
#   'VORP': 0.0,
#   'WS': 1.1,
#   'WS.48': 0.085,
#   'average.salary': 2319013,
#   'eFG.': 0.54,
#   'fix': 'tjwarren'},
#  {'Age': 22,
#   'BLK': 0.5,
#   'BLK.': 1.2,
#   'BPM': -0.3,
#   'Cluster': 8,
#   'DBPM': -0.7,
#   'FG': 6.5,
#   'FT': 2.8,
#   'FTA': 3.6,
#   'GS': 63,
#   'ORB': 1.1,
#   'STL': 1.0,
#   'STL.': 1.5,
#   'TOV.': 9.8,
#   'VORP': 1.0,
#   'WS': 4.8,
#   'WS.48': 0.098,
#   'average.salary': 16000000,
#   'eFG.': 0.512,
#   'fix': 'tobiasharris'},
#  {'Age': 28,
#   'BLK': 0.3,
#   'BLK.': 1.7,
#   'BPM': -1.3,
#   'Cluster': 1,
#   'DBPM': 0.8,
#   'FG': 1.6,
#   'FT': 0.7,
#   'FTA': 1.1,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.9,
#   'STL.': 3.3,
#   'TOV.': 15.0,
#   'VORP': 0.0,
#   'WS': 0.2,
#   'WS.48': 0.046,
#   'average.salary': 1240153,
#   'eFG.': 0.42200000000000004,
#   'fix': 'toneydouglas'},
#  {'Age': 33,
#   'BLK': 0.5,
#   'BLK.': 1.5,
#   'BPM': 3.3,
#   'Cluster': 4,
#   'DBPM': 3.7,
#   'FG': 3.6,
#   'FT': 1.3,
#   'FTA': 2.0,
#   'GS': 41,
#   'ORB': 1.6,
#   'STL': 2.0,
#   'STL.': 4.1,
#   'TOV.': 14.4,
#   'VORP': 2.2,
#   'WS': 4.1,
#   'WS.48': 0.11900000000000001,
#   'average.salary': 5000000,
#   'eFG.': 0.505,
#   'fix': 'tonyallen'},
#  {'Age': 32,
#   'BLK': 0.0,
#   'BLK.': 0.1,
#   'BPM': -2.0,
#   'Cluster': 8,
#   'DBPM': -2.2,
#   'FG': 5.9,
#   'FT': 1.9,
#   'FTA': 2.4,
#   'GS': 68,
#   'ORB': 0.2,
#   'STL': 0.6,
#   'STL.': 1.2,
#   'TOV.': 13.9,
#   'VORP': 0.0,
#   'WS': 4.1,
#   'WS.48': 0.1,
#   'average.salary': 14445313,
#   'eFG.': 0.508,
#   'fix': 'tonyparker'},
#  {'Age': 23,
#   'BLK': 0.2,
#   'BLK.': 0.6,
#   'BPM': -1.5,
#   'Cluster': 2,
#   'DBPM': -0.9,
#   'FG': 2.2,
#   'FT': 0.6,
#   'FTA': 0.8,
#   'GS': 22,
#   'ORB': 0.4,
#   'STL': 0.4,
#   'STL.': 1.2,
#   'TOV.': 10.8,
#   'VORP': 0.2,
#   'WS': 2.4,
#   'WS.48': 0.08199999999999999,
#   'average.salary': 1696412,
#   'eFG.': 0.527,
#   'fix': 'tonysnell'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': 1.9,
#   'Cluster': 5,
#   'DBPM': 1.3,
#   'FG': 4.5,
#   'FT': 1.5,
#   'FTA': 1.7,
#   'GS': 82,
#   'ORB': 0.9,
#   'STL': 1.9,
#   'STL.': 2.6,
#   'TOV.': 12.7,
#   'VORP': 2.9,
#   'WS': 6.6,
#   'WS.48': 0.10800000000000001,
#   'average.salary': 8000001,
#   'eFG.': 0.509,
#   'fix': 'trevorariza'},
#  {'Age': 27,
#   'BLK': 0.5,
#   'BLK.': 2.1,
#   'BPM': 0.2,
#   'Cluster': 3,
#   'DBPM': 0.7,
#   'FG': 2.9,
#   'FT': 1.1,
#   'FTA': 1.9,
#   'GS': 5,
#   'ORB': 1.8,
#   'STL': 0.5,
#   'STL.': 1.5,
#   'TOV.': 14.3,
#   'VORP': 0.9,
#   'WS': 3.6,
#   'WS.48': 0.11,
#   'average.salary': 4887500,
#   'eFG.': 0.518,
#   'fix': 'trevorbooker'},
#  {'Age': 22,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': -1.9,
#   'Cluster': 2,
#   'DBPM': -1.9,
#   'FG': 4.9,
#   'FT': 1.4,
#   'FTA': 1.9,
#   'GS': 43,
#   'ORB': 0.4,
#   'STL': 0.9,
#   'STL.': 1.5,
#   'TOV.': 10.4,
#   'VORP': 0.1,
#   'WS': 2.4,
#   'WS.48': 0.05,
#   'average.salary': 2758040,
#   'eFG.': 0.43,
#   'fix': 'treyburke'},
#  {'Age': 23,
#   'BLK': 0.7,
#   'BLK.': 2.2,
#   'BPM': -0.6,
#   'Cluster': 8,
#   'DBPM': -0.3,
#   'FG': 3.3,
#   'FT': 1.9,
#   'FTA': 3.0,
#   'GS': 15,
#   'ORB': 3.3,
#   'STL': 0.4,
#   'STL.': 0.8,
#   'TOV.': 12.2,
#   'VORP': 0.8,
#   'WS': 6.8,
#   'WS.48': 0.14800000000000002,
#   'average.salary': 16400000,
#   'eFG.': 0.547,
#   'fix': 'tristanthompson'},
#  {'Age': 23,
#   'BLK': 0.0,
#   'BLK.': 0.2,
#   'BPM': -4.9,
#   'Cluster': 1,
#   'DBPM': -4.6,
#   'FG': 1.3,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 0,
#   'ORB': 0.2,
#   'STL': 0.1,
#   'STL.': 0.8,
#   'TOV.': 10.5,
#   'VORP': -0.3,
#   'WS': 0.2,
#   'WS.48': 0.022000000000000002,
#   'average.salary': 881879,
#   'eFG.': 0.5,
#   'fix': 'troydaniels'},
#  {'Age': 27,
#   'BLK': 0.1,
#   'BLK.': 0.3,
#   'BPM': 0.5,
#   'Cluster': 1,
#   'DBPM': -2.1,
#   'FG': 5.4,
#   'FT': 3.5,
#   'FTA': 4.8,
#   'GS': 75,
#   'ORB': 0.6,
#   'STL': 1.2,
#   'STL.': 1.7,
#   'TOV.': 14.6,
#   'VORP': 1.7,
#   'WS': 7.0,
#   'WS.48': 0.126,
#   'average.salary': 265058,
#   'eFG.': 0.474,
#   'fix': 'tylawson'},
#  {'Age': 20,
#   'BLK': 0.2,
#   'BLK.': 1.0,
#   'BPM': -6.7,
#   'Cluster': 2,
#   'DBPM': -1.5,
#   'FG': 1.6,
#   'FT': 0.2,
#   'FTA': 0.2,
#   'GS': 1,
#   'ORB': 0.2,
#   'STL': 0.5,
#   'STL.': 2.2,
#   'TOV.': 22.2,
#   'VORP': -0.5,
#   'WS': -0.3,
#   'WS.48': -0.04,
#   'average.salary': 1662320,
#   'eFG.': 0.40299999999999997,
#   'fix': 'tylerennis'},
#  {'Age': 29,
#   'BLK': 0.2,
#   'BLK.': 1.1,
#   'BPM': -0.5,
#   'Cluster': 1,
#   'DBPM': -0.5,
#   'FG': 1.2,
#   'FT': 1.3,
#   'FTA': 1.9,
#   'GS': 8,
#   'ORB': 1.4,
#   'STL': 0.4,
#   'STL.': 1.5,
#   'TOV.': 8.1,
#   'VORP': 0.4,
#   'WS': 3.4,
#   'WS.48': 0.156,
#   'average.salary': 1185784,
#   'eFG.': 0.524,
#   'fix': 'tylerhansbrough'},
#  {'Age': 22,
#   'BLK': 0.3,
#   'BLK.': 1.3,
#   'BPM': -1.1,
#   'Cluster': 1,
#   'DBPM': 0.7,
#   'FG': 2.2,
#   'FT': 1.0,
#   'FTA': 1.5,
#   'GS': 2,
#   'ORB': 0.4,
#   'STL': 1.0,
#   'STL.': 2.9,
#   'TOV.': 13.8,
#   'VORP': 0.1,
#   'WS': 0.8,
#   'WS.48': 0.06,
#   'average.salary': 522505,
#   'eFG.': 0.473,
#   'fix': 'tylerjohnson'},
#  {'Age': 25,
#   'BLK': 0.6,
#   'BLK.': 2.3,
#   'BPM': 0.9,
#   'Cluster': 2,
#   'DBPM': 0.4,
#   'FG': 4.1,
#   'FT': 1.9,
#   'FTA': 2.3,
#   'GS': 59,
#   'ORB': 1.8,
#   'STL': 0.2,
#   'STL.': 0.5,
#   'TOV.': 9.8,
#   'VORP': 1.2,
#   'WS': 6.5,
#   'WS.48': 0.179,
#   'average.salary': 1879324,
#   'eFG.': 0.5489999999999999,
#   'fix': 'tylerzeller'},
#  {'Age': 25,
#   'BLK': 0.5,
#   'BLK.': 1.0,
#   'BPM': 1.9,
#   'Cluster': 6,
#   'DBPM': 0.1,
#   'FG': 6.6,
#   'FT': 2.6,
#   'FTA': 3.7,
#   'GS': 76,
#   'ORB': 1.0,
#   'STL': 1.3,
#   'STL.': 2.0,
#   'TOV.': 16.0,
#   'VORP': 2.6,
#   'WS': 4.6,
#   'WS.48': 0.08199999999999999,
#   'average.salary': 11000001,
#   'eFG.': 0.47700000000000004,
#   'fix': 'tyrekeevans'},
#  {'Age': 32,
#   'BLK': 1.2,
#   'BLK.': 3.2,
#   'BPM': 4.2,
#   'Cluster': 7,
#   'DBPM': 2.3,
#   'FG': 3.9,
#   'FT': 2.5,
#   'FTA': 3.4,
#   'GS': 75,
#   'ORB': 3.9,
#   'STL': 0.6,
#   'STL.': 0.9,
#   'TOV.': 16.0,
#   'VORP': 3.6,
#   'WS': 10.3,
#   'WS.48': 0.21600000000000003,
#   'average.salary': 13000000,
#   'eFG.': 0.6659999999999999,
#   'fix': 'tysonchandler'},
#  {'Age': 34,
#   'BLK': 0.2,
#   'BLK.': 1.1,
#   'BPM': -3.4,
#   'Cluster': 2,
#   'DBPM': -0.1,
#   'FG': 1.7,
#   'FT': 0.7,
#   'FTA': 1.0,
#   'GS': 25,
#   'ORB': 1.1,
#   'STL': 0.3,
#   'STL.': 1.1,
#   'TOV.': 13.3,
#   'VORP': -0.4,
#   'WS': 1.4,
#   'WS.48': 0.066,
#   'average.salary': 2793470,
#   'eFG.': 0.452,
#   'fix': 'udonishaslem'},
#  {'Age': 22,
#   'BLK': 0.3,
#   'BLK.': 0.6,
#   'BPM': 0.0,
#   'Cluster': 4,
#   'DBPM': -0.5,
#   'FG': 6.6,
#   'FT': 3.6,
#   'FTA': 4.4,
#   'GS': 71,
#   'ORB': 0.7,
#   'STL': 1.7,
#   'STL.': 2.4,
#   'TOV.': 14.3,
#   'VORP': 1.3,
#   'WS': 3.5,
#   'WS.48': 0.065,
#   'average.salary': 5371860,
#   'eFG.': 0.474,
#   'fix': 'victoroladipo'},
#  {'Age': 38,
#   'BLK': 0.2,
#   'BLK.': 1.1,
#   'BPM': -1.4,
#   'Cluster': 3,
#   'DBPM': -0.3,
#   'FG': 2.0,
#   'FT': 0.7,
#   'FTA': 0.9,
#   'GS': 1,
#   'ORB': 0.4,
#   'STL': 0.7,
#   'STL.': 2.1,
#   'TOV.': 9.1,
#   'VORP': 0.2,
#   'WS': 1.0,
#   'WS.48': 0.043,
#   'average.salary': 4088019,
#   'eFG.': 0.41700000000000004,
#   'fix': 'vincecarter'},
#  {'Age': 27,
#   'BLK': 0.0,
#   'BLK.': 0.1,
#   'BPM': -3.0,
#   'Cluster': 2,
#   'DBPM': -2.6,
#   'FG': 3.9,
#   'FT': 0.8,
#   'FTA': 1.0,
#   'GS': 36,
#   'ORB': 0.5,
#   'STL': 0.5,
#   'STL.': 1.0,
#   'TOV.': 7.2,
#   'VORP': -0.4,
#   'WS': 1.2,
#   'WS.48': 0.034,
#   'average.salary': 1533750,
#   'eFG.': 0.485,
#   'fix': 'wayneellington'},
#  {'Age': 27,
#   'BLK': 0.6,
#   'BLK.': 1.6,
#   'BPM': -1.5,
#   'Cluster': 1,
#   'DBPM': -0.6,
#   'FG': 3.8,
#   'FT': 1.2,
#   'FTA': 1.5,
#   'GS': 59,
#   'ORB': 0.9,
#   'STL': 0.8,
#   'STL.': 1.3,
#   'TOV.': 10.5,
#   'VORP': 0.3,
#   'WS': 1.7,
#   'WS.48': 0.037000000000000005,
#   'average.salary': 1163944,
#   'eFG.': 0.48,
#   'fix': 'wesleyjohnson'},
#  {'Age': 28,
#   'BLK': 0.2,
#   'BLK.': 0.4,
#   'BPM': 3.9,
#   'Cluster': 8,
#   'DBPM': 0.1,
#   'FG': 5.6,
#   'FT': 1.8,
#   'FTA': 2.4,
#   'GS': 60,
#   'ORB': 0.6,
#   'STL': 1.3,
#   'STL.': 1.9,
#   'TOV.': 9.0,
#   'VORP': 3.0,
#   'WS': 6.2,
#   'WS.48': 0.147,
#   'average.salary': 17515007,
#   'eFG.': 0.563,
#   'fix': 'wesleymatthews'},
#  {'Age': 24,
#   'BLK': 0.3,
#   'BLK.': 1.5,
#   'BPM': -0.6,
#   'Cluster': 3,
#   'DBPM': 1.1,
#   'FG': 2.6,
#   'FT': 1.3,
#   'FTA': 1.6,
#   'GS': 0,
#   'ORB': 0.4,
#   'STL': 0.8,
#   'STL.': 2.5,
#   'TOV.': 13.4,
#   'VORP': 0.3,
#   'WS': 1.3,
#   'WS.48': 0.063,
#   'average.salary': 3533333,
#   'eFG.': 0.45799999999999996,
#   'fix': 'willbarton'},
#  {'Age': 27,
#   'BLK': 0.4,
#   'BLK.': 0.9,
#   'BPM': 0.2,
#   'Cluster': 7,
#   'DBPM': -0.4,
#   'FG': 5.4,
#   'FT': 1.4,
#   'FTA': 1.8,
#   'GS': 75,
#   'ORB': 1.2,
#   'STL': 0.7,
#   'STL.': 1.2,
#   'TOV.': 9.6,
#   'VORP': 1.3,
#   'WS': 3.6,
#   'WS.48': 0.071,
#   'average.salary': 11625000,
#   'eFG.': 0.5,
#   'fix': 'wilsonchandler'},
#  {'Age': 19,
#   'BLK': 0.1,
#   'BLK.': 0.4,
#   'BPM': -4.5,
#   'Cluster': 2,
#   'DBPM': -2.7,
#   'FG': 3.7,
#   'FT': 1.9,
#   'FTA': 2.3,
#   'GS': 40,
#   'ORB': 0.4,
#   'STL': 0.7,
#   'STL.': 1.4,
#   'TOV.': 20.4,
#   'VORP': -1.2,
#   'WS': -0.7,
#   'WS.48': -0.018000000000000002,
#   'average.salary': 2411825,
#   'eFG.': 0.465,
#   'fix': 'zachlavine'},
#  {'Age': 33,
#   'BLK': 0.2,
#   'BLK.': 0.5,
#   'BPM': 1.5,
#   'Cluster': 6,
#   'DBPM': 1.1,
#   'FG': 6.4,
#   'FT': 3.2,
#   'FTA': 4.2,
#   'GS': 71,
#   'ORB': 3.2,
#   'STL': 1.0,
#   'STL.': 1.6,
#   'TOV.': 12.8,
#   'VORP': 2.0,
#   'WS': 7.2,
#   'WS.48': 0.149,
#   'average.salary': 10000000,
#   'eFG.': 0.491,
#   'fix': 'zachrandolph'},
#  {'Age': 30,
#   'BLK': 0.3,
#   'BLK.': 1.0,
#   'BPM': 1.4,
#   'Cluster': 4,
#   'DBPM': 2.2,
#   'FG': 3.3,
#   'FT': 1.7,
#   'FTA': 2.2,
#   'GS': 45,
#   'ORB': 2.7,
#   'STL': 1.1,
#   'STL.': 2.4,
#   'TOV.': 18.2,
#   'VORP': 1.5,
#   'WS': 4.2,
#   'WS.48': 0.11599999999999999,
#   'average.salary': 5200000,
#   'eFG.': 0.45399999999999996,
#   'fix': 'zazapachulia'},
#  {'Age': 25,
#   'BLK': 0.0,
#   'BLK.': 0.0,
#   'BPM': -6.5,
#   'Cluster': 2,
#   'DBPM': -4.0,
#   'FG': 0.7,
#   'FT': 0.2,
#   'FTA': 0.3,
#   'GS': 1,
#   'ORB': 0.3,
#   'STL': 0.1,
#   'STL.': 1.4,
#   'TOV.': 13.4,
#   'VORP': -0.1,
#   'WS': -0.1,
#   'WS.48': -0.042,
#   'average.salary': 1500000,
#   'eFG.': 0.41700000000000004,
#   'fix': 'zorandragic'}]
